# %%
import os
import sys
sys.path.append(os.path.expanduser('~/albatros_analysis'))
import numpy as np 
import numba as nb
import time
from scipy import linalg
from scipy import stats
from scipy import signal as sn 
from matplotlib import pyplot as plt
from datetime import datetime as dt
from src.correlations import baseband_data_classes as bdc
from src.utils import baseband_utils as butils
from src.utils import orbcomm_utils as outils
import json
# Out:
# BDC is using numpy

# %%
#define some basic functions here, like xcorr and etc

@nb.njit()
def get_common_rows(specnum0,specnum1,idxstart0,idxstart1):
    nrows0,nrows1=specnum0.shape[0],specnum1.shape[0]
    maxrows=min(nrows0,nrows1)
    rownums0=np.empty(maxrows,dtype='int64')
    rownums0[:]=-1
    rownums1=rownums0.copy()
    rowidx=rownums0.copy()
    i=0;j=0;row_count=0;
    while i<nrows0 and j<nrows1:
        if (specnum0[i]-idxstart0)==(specnum1[j]-idxstart1):
            rownums0[row_count]=i
            rownums1[row_count]=j
            rowidx[row_count]=specnum0[i]-idxstart0
            i+=1
            j+=1
            row_count+=1
        elif (specnum0[i]-idxstart0)>(specnum1[j]-idxstart1):
            j+=1
        else:
            i+=1
    return row_count,rownums0,rownums1,rowidx

@nb.njit(parallel=True)
def avg_xcorr_4bit_2ant_float(pol0,pol1,specnum0,specnum1,idxstart0,idxstart1,delay=None,freqs=None):
    row_count,rownums0,rownums1,rowidx=get_common_rows(specnum0,specnum1,idxstart0,idxstart1)
    ncols=pol0.shape[1]
#     print("ncols",ncols)
    assert pol0.shape[1]==pol1.shape[1]
    xcorr=np.zeros((row_count,ncols),dtype='complex64') # in the dev_gen_phases branch
    if delay is not None:
        for i in nb.prange(row_count):
            for j in range(ncols):
                xcorr[i,j] = pol0[rownums0[i],j]*np.conj(pol1[rownums1[i],j]*np.exp(2j*np.pi*delay[rowidx[i]]*freqs[j]))
    else:
        for i in nb.prange(row_count):
            xcorr[i,:] = pol0[rownums0[i],:]*np.conj(pol1[rownums1[i],:])
    return xcorr

def get_coarse_xcorr(f1, f2, Npfb=4096):
    if len(f1.shape) == 1:
        f1 = f1.reshape(-1, 1)
    if len(f2.shape) == 1:
        f2 = f2.reshape(-1, 1)
    chans = f1.shape[1]
    Nsmall = f1.shape[0]
    wt = np.zeros(2 * Nsmall)
    wt[:Nsmall] = 1
    n_avg = np.fft.irfft(np.fft.rfft(wt) * np.conj(np.fft.rfft(wt)))
#     print(n_avg)
#     n_avg[Nsmall] = np.nan
#     print(n_avg[Nsmall-10:Nsmall+10])
    n_avg = np.tile(n_avg, chans).reshape(chans, 2*Nsmall)
#     print(n_avg.shape)
    bigf1 = np.vstack([f1, np.zeros(f1.shape, dtype=f1.dtype)])
    bigf2 = np.vstack([f2, np.zeros(f2.shape, dtype=f2.dtype)])
    bigf1 = bigf1.T.copy()
    bigf2 = bigf2.T.copy()
    bigf1f = np.fft.fft(bigf1,axis=1)
    bigf2f = np.fft.fft(bigf2,axis=1)
    xx = bigf1f * np.conj(bigf2f)
    xcorr = np.fft.ifft(xx,axis=1)
    xcorr = xcorr / n_avg
    xcorr[:,Nsmall] = np.nan
    return xcorr

# %%
config_path = '/home/thomasb/albatros_analysis/scripts/orbcomm'
config_name = 'config2.json'
bl_ants = ['Antenna 1', 'Antenna 2']
rel_start_t, rel_end_t = 10545, 10795

names, paths, coords = [], [], []
with open(f"{config_path}/{config_name}", "r") as f:
    config = json.load(f)
    for i, (ant, details) in enumerate(config["antennas"].items()):
        if details['name'] in bl_ants:
            names.append(details['name'])
            paths.append(details['path'])
            coords.append(details['coordinates'])

    global_start_time = config["correlation"]["start_timestamp"]
    global_end_time = config["correlation"]["end_timestamp"]
    c_acclen = config["correlation"]["coarse_acclen"]

# %%
sat_ID = 57166 #hard-coded for now

def get_coarse_offset(paths, coords, pulse_start_time, global_start_time, sat_ID, T_SPECTRA = 4096/250e6, c_acclen=10**6):

    tle_path =  outils.get_tle_file(global_start_time, "/project/rrg-sievers/mohanagr/OCOMM_TLES")
    chunk_len = c_acclen * T_SPECTRA
    pulse_dur_secs = 1000
    start_t, end_t = global_start_time + pulse_start_time, global_start_time + pulse_start_time + pulse_dur_secs
    pulse_dur_chunks = np.ceil(pulse_dur_secs / chunk_len)

    freqs = 250e6 * (1 - np.arange(1852, 1834, -1) / 4096)

    #get files and indices
    files_1, idx_1 = butils.get_init_info(start_t, end_t, paths[0])
    files_2, idx_2 = butils.get_init_info(start_t, end_t, paths[1])

    #channels should be the same for both 
    channels = bdc.get_header(files_1[0])["channels"].astype('int64')
    chanstart = np.where(channels == 1834)[0][0] 
    chanend = np.where(channels == 1852)[0][0]
    nchans=chanend-chanstart

    #get baseband file iterator objects
    ant1_c = bdc.BasebandFileIterator(files_1, 0, idx_1, c_acclen, nchunks=pulse_dur_chunks, chanstart=chanstart, chanend=chanend, type='float')
    ant2_c = bdc.BasebandFileIterator(files_2, 0, idx_2, c_acclen, nchunks=pulse_dur_chunks, chanstart=chanstart, chanend=chanend, type='float')

    #set up pol arrays
    p0_a1 = np.zeros((c_acclen, nchans), dtype="complex128")
    p0_a2 = np.zeros((c_acclen, nchans), dtype="complex128")
    p0_a2_delayed = np.zeros((c_acclen, nchans), dtype="complex128")

    #check that we have a good starting chunk
    a1_c_start = ant1_c.spec_num_start
    a2_c_start = ant2_c.spec_num_start
    for i, (chunk1, chunk2) in enumerate(zip(ant1_c, ant2_c)):
            perc_missing_a1 = (1 - len(chunk1["specnums"]) / c_acclen) * 100
            perc_missing_a2 = (1 - len(chunk2["specnums"]) / c_acclen) * 100
            print("missing a1", perc_missing_a1, "missing a2", perc_missing_a2)
            if perc_missing_a1 > 10 or perc_missing_a2 > 10:
                a1_c_start = ant1_c.spec_num_start
                a2_c_start = ant2_c.spec_num_start
                print("skipping")
                continue
            print(chunk1["specnums"] - a1_c_start)
            outils.make_continuous(
                p0_a1, chunk1["pol0"], chunk1["specnums"] - a1_c_start
            )
            outils.make_continuous(
                p0_a2, chunk2["pol0"], chunk2["specnums"] - a2_c_start
            )
            break


    #get delays
    delays = np.zeros(c_acclen)
    d = outils.get_sat_delay(
                    coords[0],
                    coords[1],
                    tle_path,
                    start_t,
                    pulse_dur_secs+1,
                    sat_ID,
                )
    delays = np.interp(np.arange(0, c_acclen) * T_SPECTRA, 
                    np.arange(0, pulse_dur_secs+1), 
                    d)

    delays = np.asarray(delays)

    outils.apply_delay(p0_a2, p0_a2_delayed, -delays, freqs)

    xc_uncorrected = np.fft.fftshift(get_coarse_xcorr(p0_a1,p0_a2),axes=1)
    xc_corrected = np.fft.fftshift(get_coarse_xcorr(p0_a1,p0_a2_delayed),axes=1)

    return xc_uncorrected, xc_corrected

# %%
xc_uncorr, xc_corr = get_coarse_offset(paths, coords, 10545, global_start_time, 57166)
# Out:
# Not reading any data
# ACCLEN RECEIVED IS 1000000
# took 0.486 seconds to read raw data on  /scratch/mohanagr/summer_2025/baseband/mars1/17531/1753143351.raw
# START SPECNUM IS 1811749580 obj start at 1810895088
# ACCLEN RECEIVED IS 1000000
# took 0.486 seconds to read raw data on  /scratch/mohanagr/summer_2025/baseband/mars2/17531/1753143363.raw
# START SPECNUM IS 1696263590 obj start at 1696141520
# print shape of my pols 1000000 18
# Took 0.04502582550048828 to unpack
# print shape of my pols 1000000 18
# Took 0.04199838638305664 to unpack
# missing a1 0.0 missing a2 0.0
# [     0      1      2 ... 999997 999998 999999]
# catalog #57166 epoch 2025-07-21 22:21:37 UTC
# one delay prediction: 0.21079564094543457

# %%
#UNCORRECTED
center = c_acclen
dN= 100000
fig,ax=plt.subplots(6,3)
fig.set_size_inches(10,12)
ax=ax.flatten()
for cc in range(18):
    mm=np.argmax(np.abs(xc_uncorr[cc,center-dN:center+dN]))
    ax[cc].set_title(f"{mm}")
    ax[cc].plot(np.abs(xc_uncorr[cc,center-dN:center+dN]))
plt.tight_layout()

# %%
#CORRECTED
fig,ax=plt.subplots(6,3)
fig.set_size_inches(10,12)
ax=ax.flatten()
for cc in range(18):
    mm=np.argmax(np.abs(xc_corr[cc,center-dN:center+dN]))
    ax[cc].set_title(f"{mm}")
    #ax[cc].plot(np.abs(xc_uncorrected[cc, peak_center - 200:peak_center + 200]))
    ax[cc].plot(np.abs(xc_corr[cc,center-dN:center+dN]))
plt.tight_layout()

# %%
peak=np.argmax(np.abs(xc_corr[3,center-dN:center+dN]))
plt.plot(np.abs(xc_corr[3,center-dN:center+dN]))
plt.title(f"{peak}")
plt.tight_layout()

# %%
#Zoomed in!

dN= 100000
fig,ax=plt.subplots(6,3)
fig.set_size_inches(10,12)
ax=ax.flatten()
for cc in range(18):
    peak_data = np.abs(xc_corr[cc,c_acclen - dN:c_acclen + dN])
    peak_location = np.argmax(peak_data)
    ax[cc].set_title(f"{peak_location}")
    ax[cc].plot(peak_data[peak_location - 500:peak_location + 500])
plt.tight_layout()

# %%
#need to clean this part up.


peak_center = c_acclen - (dN - 62421)

#get the data you want to look at
data = np.abs(xc_corr[3][peak_center-200: peak_center+200])
plt.plot(data)

#determine the minimum prominence we want
noise_level = np.std(data)
desired_snr = 5 
min_prominence = desired_snr * noise_level
print(min_prominence)

#get our peak information

# make relative !!!!!!!
peaks_total = sn.find_peaks(data, height=0.01)
peaks_loud = sn.find_peaks(data, prominence=min_prominence)

print(peaks_total)
# Out:
# 0.12736009279438976
# (array([200]), {'peak_heights': array([0.39448733])})

# %%
peak_location = np.argmax(data)
peak_data = data[peak_location - 200:peak_location + 200]
peaks_total = sn.find_peaks(data, height=0.001)
heights = peaks_total[1]['peak_heights']
height_indices = np.argsort(heights)

tallest = heights[height_indices[-1]]
reps, total = 4, 0
for i in range(reps):
    total += (tallest - heights[height_indices[-(i+2)]])
rel_ratio = (total/(tallest * reps))
print("\nRELIABILITY RATIO:", rel_ratio)

if rel_ratio < 0.15:
    sat_label = "UNRELIABLE"
elif rel_ratio > 0.7:
    sat_label = "RELIABLE"
else:
    sat_label = "UNCLEAR"

print("\nSTATUS:", sat_label)
# Out:
# RELIABILITY RATIO: 0.024161693394190966
#
# STATUS: UNRELIABLE

# %% [markdown]
# <h1 style="font-size:30pt">VISIBILITY</h1>

# %%
idx_correction=86568-100000
if idx_correction>0:
    idx1_v = idx1 + idx_correction
    idx2_v = idx2
else:
    idx2_v = idx2 + np.abs(idx_correction)
    idx1_v = idx1
print("Corrected Starting Indices:", idx1_v, idx2_v)
# Out:
# Corrected Starting Indices: 305176 2027592

# %%
ant1_v = bdc.BasebandFileIterator(files_a1, 0, idx1_v, v_acclen, nchunks=v_nchunks, chanstart=chanstart, chanend=chanend, type='float')
ant2_v = bdc.BasebandFileIterator(files_a2, 0, idx2_v, v_acclen, nchunks=v_nchunks, chanstart=chanstart, chanend=chanend, type='float')
# Out:
# ACCLEN RECEIVED IS 30000
# took 0.266 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721800712.raw
# START SPECNUM IS 1033442694 obj start at 1033137518
# ACCLEN RECEIVED IS 30000
# took 0.173 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721800684.raw
# START SPECNUM IS 1089686353 obj start at 1087658761

# %%
m1=ant1_v.spec_num_start
m2=ant2_v.spec_num_start
visibility_phased = np.zeros((v_nchunks,len(ant1_v.channel_idxs)), dtype='complex64')
st=time.time()
        
for i, (chunk1,chunk2) in enumerate(zip(ant1_v,ant2_v)):
        # pol00[i,:] = cr.avg_xcorr_4bit_2ant(chunk1['pol0'], chunk2['pol0'],chnk1['specnums'],chunk2['specnums'],m1+i*acclen,m2+i*acclen)
        xcorr = avg_xcorr_4bit_2ant_float(
                chunk1['pol0'], 
                chunk2['pol0'],
                chunk1['specnums'],
                chunk2['specnums'],
                m1+i*v_acclen,
                m2+i*v_acclen)
        visibility_phased[i,:] = np.sum(xcorr,axis=0)/v_acclen
        print("CHUNK", i, " has ", xcorr.shape[0], " rows")
print("Time taken final:", time.time()-st)
visibility_phased = np.ma.masked_invalid(visibility_phased)
# Out:
# CHUNK 0  has  30000  rows
# CHUNK 1  has  30000  rows
# CHUNK 2  has  30000  rows
# CHUNK 3  has  30000  rows
# CHUNK 4  has  30000  rows
# CHUNK 5  has  30000  rows
# CHUNK 6  has  30000  rows
# CHUNK 7  has  30000  rows
# CHUNK 8  has  30000  rows
# CHUNK 9  has  30000  rows
# CHUNK 10  has  30000  rows
# CHUNK 11  has  30000  rows
# CHUNK 12  has  30000  rows
# CHUNK 13  has  30000  rows
# CHUNK 14  has  30000  rows
# CHUNK 15  has  30000  rows
# CHUNK 16  has  30000  rows
# CHUNK 17  has  30000  rows
# CHUNK 18  has  30000  rows
# CHUNK 19  has  30000  rows
# CHUNK 20  has  30000  rows
# CHUNK 21  has  30000  rows
# took 1.306 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721800729.raw
# CHUNK 22  has  30000  rows
# CHUNK 23  has  30000  rows
# CHUNK 24  has  30000  rows
# CHUNK 25  has  30000  rows
# CHUNK 26  has  30000  rows
# CHUNK 27  has  30000  rows
# CHUNK 28  has  30000  rows
# CHUNK 29  has  30000  rows
# CHUNK 30  has  30000  rows
# CHUNK 31  has  30000  rows
# CHUNK 32  has  30000  rows
# CHUNK 33  has  30000  rows
# CHUNK 34  has  30000  rows
# CHUNK 35  has  30000  rows
# CHUNK 36  has  30000  rows
# CHUNK 37  has  30000  rows
# CHUNK 38  has  30000  rows
# CHUNK 39  has  30000  rows
# CHUNK 40  has  30000  rows
# CHUNK 41  has  30000  rows
# CHUNK 42  has  30000  rows
# CHUNK 43  has  30000  rows
# CHUNK 44  has  30000  rows
# CHUNK 45  has  30000  rows
# CHUNK 46  has  30000  rows
# CHUNK 47  has  30000  rows
# CHUNK 48  has  30000  rows
# CHUNK 49  has  30000  rows
# CHUNK 50  has  30000  rows
# CHUNK 51  has  30000  rows
# CHUNK 52  has  30000  rows
# CHUNK 53  has  30000  rows
# CHUNK 54  has  30000  rows
# CHUNK 55  has  30000  rows
# CHUNK 56  has  30000  rows
# CHUNK 57  has  30000  rows
# CHUNK 58  has  30000  rows
# CHUNK 59  has  30000  rows
# CHUNK 60  has  30000  rows
# CHUNK 61  has  30000  rows
# CHUNK 62  has  30000  rows
# CHUNK 63  has  30000  rows
# CHUNK 64  has  30000  rows
# CHUNK 65  has  30000  rows
# CHUNK 66  has  30000  rows
# CHUNK 67  has  30000  rows
# CHUNK 68  has  30000  rows
# CHUNK 69  has  30000  rows
# CHUNK 70  has  30000  rows
# CHUNK 71  has  30000  rows
# CHUNK 72  has  30000  rows
# CHUNK 73  has  30000  rows
# CHUNK 74  has  30000  rows
# CHUNK 75  has  30000  rows
# CHUNK 76  has  30000  rows
# CHUNK 77  has  30000  rows
# CHUNK 78  has  30000  rows
# CHUNK 79  has  30000  rows
# took 1.345 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721800757.raw
# CHUNK 80  has  30000  rows
# CHUNK 81  has  30000  rows
# CHUNK 82  has  30000  rows
# CHUNK 83  has  30000  rows
# CHUNK 84  has  30000  rows
# CHUNK 85  has  30000  rows
# CHUNK 86  has  30000  rows
# CHUNK 87  has  30000  rows
# CHUNK 88  has  30000  rows
# CHUNK 89  has  30000  rows
# CHUNK 90  has  30000  rows
# CHUNK 91  has  30000  rows
# CHUNK 92  has  30000  rows
# CHUNK 93  has  30000  rows
# CHUNK 94  has  30000  rows
# CHUNK 95  has  30000  rows
# CHUNK 96  has  30000  rows
# CHUNK 97  has  30000  rows
# CHUNK 98  has  30000  rows
# CHUNK 99  has  30000  rows
# CHUNK 100  has  30000  rows
# CHUNK 101  has  30000  rows
# CHUNK 102  has  30000  rows
# CHUNK 103  has  30000  rows
# CHUNK 104  has  30000  rows
# CHUNK 105  has  30000  rows
# CHUNK 106  has  30000  rows
# CHUNK 107  has  30000  rows
# CHUNK 108  has  30000  rows
# CHUNK 109  has  30000  rows
# CHUNK 110  has  30000  rows
# CHUNK 111  has  30000  rows
# CHUNK 112  has  30000  rows
# took 1.278 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721800773.raw
# CHUNK 113  has  30000  rows
# CHUNK 114  has  30000  rows
# CHUNK 115  has  30000  rows
# CHUNK 116  has  30000  rows
# CHUNK 117  has  30000  rows
# CHUNK 118  has  30000  rows
# CHUNK 119  has  30000  rows
# CHUNK 120  has  30000  rows
# CHUNK 121  has  30000  rows
# CHUNK 122  has  30000  rows
# CHUNK 123  has  30000  rows
# CHUNK 124  has  30000  rows
# CHUNK 125  has  30000  rows
# CHUNK 126  has  30000  rows
# CHUNK 127  has  30000  rows
# CHUNK 128  has  30000  rows
# CHUNK 129  has  30000  rows
# CHUNK 130  has  30000  rows
# CHUNK 131  has  30000  rows
# CHUNK 132  has  30000  rows
# CHUNK 133  has  30000  rows
# CHUNK 134  has  30000  rows
# CHUNK 135  has  30000  rows
# CHUNK 136  has  30000  rows
# CHUNK 137  has  30000  rows
# CHUNK 138  has  30000  rows
# CHUNK 139  has  30000  rows
# CHUNK 140  has  30000  rows
# CHUNK 141  has  30000  rows
# CHUNK 142  has  30000  rows
# CHUNK 143  has  30000  rows
# CHUNK 144  has  30000  rows
# CHUNK 145  has  30000  rows
# CHUNK 146  has  30000  rows
# CHUNK 147  has  30000  rows
# CHUNK 148  has  30000  rows
# CHUNK 149  has  30000  rows
# CHUNK 150  has  30000  rows
# CHUNK 151  has  30000  rows
# CHUNK 152  has  30000  rows
# CHUNK 153  has  30000  rows
# CHUNK 154  has  30000  rows
# CHUNK 155  has  30000  rows
# CHUNK 156  has  30000  rows
# CHUNK 157  has  30000  rows
# CHUNK 158  has  30000  rows
# CHUNK 159  has  30000  rows
# CHUNK 160  has  30000  rows
# CHUNK 161  has  30000  rows
# CHUNK 162  has  30000  rows
# CHUNK 163  has  30000  rows
# CHUNK 164  has  30000  rows
# CHUNK 165  has  30000  rows
# CHUNK 166  has  30000  rows
# CHUNK 167  has  30000  rows
# CHUNK 168  has  30000  rows
# CHUNK 169  has  30000  rows
# took 1.334 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721800801.raw
# CHUNK 170  has  30000  rows
# CHUNK 171  has  30000  rows
# CHUNK 172  has  30000  rows
# CHUNK 173  has  30000  rows
# CHUNK 174  has  30000  rows
# CHUNK 175  has  30000  rows
# CHUNK 176  has  30000  rows
# CHUNK 177  has  30000  rows
# CHUNK 178  has  30000  rows
# CHUNK 179  has  30000  rows
# CHUNK 180  has  30000  rows
# CHUNK 181  has  30000  rows
# CHUNK 182  has  30000  rows
# CHUNK 183  has  30000  rows
# CHUNK 184  has  30000  rows
# CHUNK 185  has  30000  rows
# CHUNK 186  has  30000  rows
# CHUNK 187  has  30000  rows
# CHUNK 188  has  30000  rows
# CHUNK 189  has  30000  rows
# CHUNK 190  has  30000  rows
# CHUNK 191  has  30000  rows
# CHUNK 192  has  30000  rows
# CHUNK 193  has  30000  rows
# CHUNK 194  has  30000  rows
# CHUNK 195  has  30000  rows
# CHUNK 196  has  30000  rows
# CHUNK 197  has  30000  rows
# CHUNK 198  has  30000  rows
# CHUNK 199  has  30000  rows
# CHUNK 200  has  30000  rows
# CHUNK 201  has  30000  rows
# CHUNK 202  has  30000  rows
# took 1.290 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721800817.raw
# CHUNK 203  has  30000  rows
# CHUNK 204  has  30000  rows
# CHUNK 205  has  30000  rows
# CHUNK 206  has  30000  rows
# CHUNK 207  has  30000  rows
# CHUNK 208  has  30000  rows
# CHUNK 209  has  30000  rows
# CHUNK 210  has  30000  rows
# CHUNK 211  has  30000  rows
# CHUNK 212  has  30000  rows
# CHUNK 213  has  30000  rows
# CHUNK 214  has  30000  rows
# CHUNK 215  has  30000  rows
# CHUNK 216  has  30000  rows
# CHUNK 217  has  30000  rows
# CHUNK 218  has  30000  rows
# CHUNK 219  has  30000  rows
# CHUNK 220  has  30000  rows
# CHUNK 221  has  30000  rows
# CHUNK 222  has  30000  rows
# CHUNK 223  has  30000  rows
# CHUNK 224  has  30000  rows
# CHUNK 225  has  30000  rows
# CHUNK 226  has  30000  rows
# CHUNK 227  has  30000  rows
# CHUNK 228  has  30000  rows
# CHUNK 229  has  30000  rows
# CHUNK 230  has  30000  rows
# CHUNK 231  has  30000  rows
# CHUNK 232  has  30000  rows
# CHUNK 233  has  30000  rows
# CHUNK 234  has  30000  rows
# CHUNK 235  has  30000  rows
# CHUNK 236  has  30000  rows
# CHUNK 237  has  30000  rows
# CHUNK 238  has  30000  rows
# CHUNK 239  has  30000  rows
# CHUNK 240  has  30000  rows
# CHUNK 241  has  30000  rows
# CHUNK 242  has  30000  rows
# CHUNK 243  has  30000  rows
# CHUNK 244  has  30000  rows
# CHUNK 245  has  30000  rows
# CHUNK 246  has  30000  rows
# CHUNK 247  has  30000  rows
# CHUNK 248  has  30000  rows
# CHUNK 249  has  30000  rows
# CHUNK 250  has  30000  rows
# CHUNK 251  has  30000  rows
# CHUNK 252  has  30000  rows
# CHUNK 253  has  30000  rows
# CHUNK 254  has  30000  rows
# CHUNK 255  has  30000  rows
# CHUNK 256  has  30000  rows
# CHUNK 257  has  30000  rows
# CHUNK 258  has  30000  rows
# CHUNK 259  has  30000  rows
# took 1.268 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721800846.raw
# CHUNK 260  has  30000  rows
# CHUNK 261  has  30000  rows
# CHUNK 262  has  30000  rows
# CHUNK 263  has  30000  rows
# CHUNK 264  has  30000  rows
# CHUNK 265  has  30000  rows
# CHUNK 266  has  30000  rows
# CHUNK 267  has  30000  rows
# CHUNK 268  has  30000  rows
# CHUNK 269  has  30000  rows
# CHUNK 270  has  30000  rows
# CHUNK 271  has  30000  rows
# CHUNK 272  has  30000  rows
# CHUNK 273  has  30000  rows
# CHUNK 274  has  30000  rows
# CHUNK 275  has  30000  rows
# CHUNK 276  has  30000  rows
# CHUNK 277  has  30000  rows
# CHUNK 278  has  30000  rows
# CHUNK 279  has  30000  rows
# CHUNK 280  has  30000  rows
# CHUNK 281  has  30000  rows
# CHUNK 282  has  30000  rows
# CHUNK 283  has  30000  rows
# CHUNK 284  has  30000  rows
# CHUNK 285  has  30000  rows
# CHUNK 286  has  30000  rows
# CHUNK 287  has  30000  rows
# CHUNK 288  has  30000  rows
# CHUNK 289  has  30000  rows
# CHUNK 290  has  30000  rows
# CHUNK 291  has  30000  rows
# CHUNK 292  has  30000  rows
# took 1.355 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721800862.raw
# CHUNK 293  has  30000  rows
# CHUNK 294  has  30000  rows
# CHUNK 295  has  30000  rows
# CHUNK 296  has  30000  rows
# CHUNK 297  has  30000  rows
# CHUNK 298  has  30000  rows
# CHUNK 299  has  30000  rows
# CHUNK 300  has  30000  rows
# CHUNK 301  has  30000  rows
# CHUNK 302  has  30000  rows
# CHUNK 303  has  30000  rows
# CHUNK 304  has  30000  rows
# CHUNK 305  has  30000  rows
# CHUNK 306  has  30000  rows
# CHUNK 307  has  30000  rows
# CHUNK 308  has  30000  rows
# CHUNK 309  has  30000  rows
# CHUNK 310  has  30000  rows
# CHUNK 311  has  30000  rows
# CHUNK 312  has  30000  rows
# CHUNK 313  has  30000  rows
# CHUNK 314  has  30000  rows
# CHUNK 315  has  30000  rows
# CHUNK 316  has  30000  rows
# CHUNK 317  has  30000  rows
# CHUNK 318  has  30000  rows
# CHUNK 319  has  30000  rows
# CHUNK 320  has  30000  rows
# CHUNK 321  has  30000  rows
# CHUNK 322  has  30000  rows
# CHUNK 323  has  30000  rows
# CHUNK 324  has  30000  rows
# CHUNK 325  has  30000  rows
# CHUNK 326  has  30000  rows
# CHUNK 327  has  30000  rows
# CHUNK 328  has  30000  rows
# CHUNK 329  has  30000  rows
# CHUNK 330  has  30000  rows
# CHUNK 331  has  30000  rows
# CHUNK 332  has  30000  rows
# CHUNK 333  has  30000  rows
# CHUNK 334  has  30000  rows
# CHUNK 335  has  30000  rows
# CHUNK 336  has  30000  rows
# CHUNK 337  has  30000  rows
# CHUNK 338  has  30000  rows
# CHUNK 339  has  30000  rows
# CHUNK 340  has  30000  rows
# CHUNK 341  has  30000  rows
# CHUNK 342  has  30000  rows
# CHUNK 343  has  30000  rows
# CHUNK 344  has  30000  rows
# CHUNK 345  has  30000  rows
# CHUNK 346  has  30000  rows
# CHUNK 347  has  30000  rows
# CHUNK 348  has  30000  rows
# CHUNK 349  has  30000  rows
# CHUNK 350  has  30000  rows
# took 1.352 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721800890.raw
# CHUNK 351  has  30000  rows
# CHUNK 352  has  30000  rows
# CHUNK 353  has  30000  rows
# CHUNK 354  has  30000  rows
# CHUNK 355  has  30000  rows
# CHUNK 356  has  30000  rows
# CHUNK 357  has  30000  rows
# CHUNK 358  has  30000  rows
# CHUNK 359  has  30000  rows
# CHUNK 360  has  30000  rows
# CHUNK 361  has  30000  rows
# CHUNK 362  has  30000  rows
# CHUNK 363  has  30000  rows
# CHUNK 364  has  30000  rows
# CHUNK 365  has  30000  rows
# CHUNK 366  has  30000  rows
# CHUNK 367  has  30000  rows
# CHUNK 368  has  30000  rows
# CHUNK 369  has  30000  rows
# CHUNK 370  has  30000  rows
# CHUNK 371  has  30000  rows
# CHUNK 372  has  30000  rows
# CHUNK 373  has  30000  rows
# CHUNK 374  has  30000  rows
# CHUNK 375  has  30000  rows
# CHUNK 376  has  30000  rows
# CHUNK 377  has  30000  rows
# CHUNK 378  has  30000  rows
# CHUNK 379  has  30000  rows
# CHUNK 380  has  30000  rows
# CHUNK 381  has  30000  rows
# CHUNK 382  has  30000  rows
# took 1.328 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721800906.raw
# CHUNK 383  has  30000  rows
# CHUNK 384  has  30000  rows
# CHUNK 385  has  30000  rows
# CHUNK 386  has  30000  rows
# CHUNK 387  has  30000  rows
# CHUNK 388  has  30000  rows
# CHUNK 389  has  30000  rows
# CHUNK 390  has  30000  rows
# CHUNK 391  has  30000  rows
# CHUNK 392  has  30000  rows
# CHUNK 393  has  30000  rows
# CHUNK 394  has  30000  rows
# CHUNK 395  has  30000  rows
# CHUNK 396  has  30000  rows
# CHUNK 397  has  30000  rows
# CHUNK 398  has  30000  rows
# CHUNK 399  has  30000  rows
# CHUNK 400  has  30000  rows
# CHUNK 401  has  30000  rows
# CHUNK 402  has  30000  rows
# CHUNK 403  has  30000  rows
# CHUNK 404  has  30000  rows
# CHUNK 405  has  30000  rows
# CHUNK 406  has  30000  rows
# CHUNK 407  has  30000  rows
# CHUNK 408  has  30000  rows
# CHUNK 409  has  30000  rows
# CHUNK 410  has  30000  rows
# CHUNK 411  has  30000  rows
# CHUNK 412  has  30000  rows
# CHUNK 413  has  30000  rows
# CHUNK 414  has  30000  rows
# CHUNK 415  has  30000  rows
# CHUNK 416  has  30000  rows
# CHUNK 417  has  30000  rows
# CHUNK 418  has  30000  rows
# CHUNK 419  has  30000  rows
# CHUNK 420  has  30000  rows
# CHUNK 421  has  30000  rows
# CHUNK 422  has  30000  rows
# CHUNK 423  has  30000  rows
# CHUNK 424  has  30000  rows
# CHUNK 425  has  30000  rows
# CHUNK 426  has  30000  rows
# CHUNK 427  has  30000  rows
# CHUNK 428  has  30000  rows
# CHUNK 429  has  30000  rows
# CHUNK 430  has  30000  rows
# CHUNK 431  has  30000  rows
# CHUNK 432  has  30000  rows
# CHUNK 433  has  30000  rows
# CHUNK 434  has  30000  rows
# CHUNK 435  has  30000  rows
# CHUNK 436  has  30000  rows
# CHUNK 437  has  30000  rows
# CHUNK 438  has  30000  rows
# CHUNK 439  has  30000  rows
# CHUNK 440  has  30000  rows
# took 1.291 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721800934.raw
# CHUNK 441  has  30000  rows
# CHUNK 442  has  30000  rows
# CHUNK 443  has  30000  rows
# CHUNK 444  has  30000  rows
# CHUNK 445  has  30000  rows
# CHUNK 446  has  30000  rows
# CHUNK 447  has  30000  rows
# CHUNK 448  has  30000  rows
# CHUNK 449  has  30000  rows
# CHUNK 450  has  30000  rows
# CHUNK 451  has  30000  rows
# CHUNK 452  has  30000  rows
# CHUNK 453  has  30000  rows
# CHUNK 454  has  30000  rows
# CHUNK 455  has  30000  rows
# CHUNK 456  has  30000  rows
# CHUNK 457  has  30000  rows
# CHUNK 458  has  30000  rows
# CHUNK 459  has  30000  rows
# CHUNK 460  has  30000  rows
# CHUNK 461  has  30000  rows
# CHUNK 462  has  30000  rows
# CHUNK 463  has  30000  rows
# CHUNK 464  has  30000  rows
# CHUNK 465  has  30000  rows
# CHUNK 466  has  30000  rows
# CHUNK 467  has  30000  rows
# CHUNK 468  has  30000  rows
# CHUNK 469  has  30000  rows
# CHUNK 470  has  30000  rows
# CHUNK 471  has  30000  rows
# CHUNK 472  has  30000  rows
# CHUNK 473  has  30000  rows
# took 1.362 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721800950.raw
# CHUNK 474  has  30000  rows
# CHUNK 475  has  30000  rows
# CHUNK 476  has  30000  rows
# CHUNK 477  has  30000  rows
# CHUNK 478  has  30000  rows
# CHUNK 479  has  30000  rows
# CHUNK 480  has  30000  rows
# CHUNK 481  has  30000  rows
# CHUNK 482  has  30000  rows
# CHUNK 483  has  30000  rows
# CHUNK 484  has  30000  rows
# CHUNK 485  has  30000  rows
# CHUNK 486  has  30000  rows
# CHUNK 487  has  30000  rows
# CHUNK 488  has  30000  rows
# CHUNK 489  has  30000  rows
# CHUNK 490  has  30000  rows
# CHUNK 491  has  30000  rows
# CHUNK 492  has  30000  rows
# CHUNK 493  has  30000  rows
# CHUNK 494  has  30000  rows
# CHUNK 495  has  30000  rows
# CHUNK 496  has  30000  rows
# CHUNK 497  has  30000  rows
# CHUNK 498  has  30000  rows
# CHUNK 499  has  30000  rows
# CHUNK 500  has  30000  rows
# CHUNK 501  has  30000  rows
# CHUNK 502  has  30000  rows
# CHUNK 503  has  30000  rows
# CHUNK 504  has  30000  rows
# CHUNK 505  has  30000  rows
# CHUNK 506  has  30000  rows
# CHUNK 507  has  30000  rows
# CHUNK 508  has  30000  rows
# CHUNK 509  has  30000  rows
# CHUNK 510  has  30000  rows
# CHUNK 511  has  30000  rows
# CHUNK 512  has  30000  rows
# CHUNK 513  has  30000  rows
# CHUNK 514  has  30000  rows
# CHUNK 515  has  30000  rows
# CHUNK 516  has  30000  rows
# CHUNK 517  has  30000  rows
# CHUNK 518  has  30000  rows
# CHUNK 519  has  30000  rows
# CHUNK 520  has  30000  rows
# CHUNK 521  has  30000  rows
# CHUNK 522  has  30000  rows
# CHUNK 523  has  30000  rows
# CHUNK 524  has  30000  rows
# CHUNK 525  has  30000  rows
# CHUNK 526  has  30000  rows
# CHUNK 527  has  30000  rows
# CHUNK 528  has  30000  rows
# CHUNK 529  has  30000  rows
# CHUNK 530  has  30000  rows
# took 1.293 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721800979.raw
# CHUNK 531  has  30000  rows
# CHUNK 532  has  30000  rows
# CHUNK 533  has  30000  rows
# CHUNK 534  has  30000  rows
# CHUNK 535  has  30000  rows
# CHUNK 536  has  30000  rows
# CHUNK 537  has  30000  rows
# CHUNK 538  has  30000  rows
# CHUNK 539  has  30000  rows
# CHUNK 540  has  30000  rows
# CHUNK 541  has  30000  rows
# CHUNK 542  has  30000  rows
# CHUNK 543  has  30000  rows
# CHUNK 544  has  30000  rows
# CHUNK 545  has  30000  rows
# CHUNK 546  has  30000  rows
# CHUNK 547  has  30000  rows
# CHUNK 548  has  30000  rows
# CHUNK 549  has  30000  rows
# CHUNK 550  has  30000  rows
# CHUNK 551  has  30000  rows
# CHUNK 552  has  30000  rows
# CHUNK 553  has  30000  rows
# CHUNK 554  has  30000  rows
# CHUNK 555  has  30000  rows
# CHUNK 556  has  30000  rows
# CHUNK 557  has  30000  rows
# CHUNK 558  has  30000  rows
# CHUNK 559  has  30000  rows
# CHUNK 560  has  30000  rows
# CHUNK 561  has  30000  rows
# CHUNK 562  has  30000  rows
# CHUNK 563  has  30000  rows
# took 1.372 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721800995.raw
# CHUNK 564  has  30000  rows
# CHUNK 565  has  30000  rows
# CHUNK 566  has  30000  rows
# CHUNK 567  has  30000  rows
# CHUNK 568  has  30000  rows
# CHUNK 569  has  30000  rows
# CHUNK 570  has  30000  rows
# CHUNK 571  has  30000  rows
# CHUNK 572  has  30000  rows
# CHUNK 573  has  30000  rows
# CHUNK 574  has  30000  rows
# CHUNK 575  has  30000  rows
# CHUNK 576  has  30000  rows
# CHUNK 577  has  30000  rows
# CHUNK 578  has  30000  rows
# CHUNK 579  has  30000  rows
# CHUNK 580  has  30000  rows
# CHUNK 581  has  30000  rows
# CHUNK 582  has  30000  rows
# CHUNK 583  has  30000  rows
# CHUNK 584  has  30000  rows
# CHUNK 585  has  30000  rows
# CHUNK 586  has  30000  rows
# CHUNK 587  has  30000  rows
# CHUNK 588  has  30000  rows
# CHUNK 589  has  30000  rows
# CHUNK 590  has  30000  rows
# CHUNK 591  has  30000  rows
# CHUNK 592  has  30000  rows
# CHUNK 593  has  30000  rows
# CHUNK 594  has  30000  rows
# CHUNK 595  has  30000  rows
# CHUNK 596  has  30000  rows
# CHUNK 597  has  30000  rows
# CHUNK 598  has  30000  rows
# CHUNK 599  has  30000  rows
# CHUNK 600  has  30000  rows
# CHUNK 601  has  30000  rows
# CHUNK 602  has  30000  rows
# CHUNK 603  has  30000  rows
# CHUNK 604  has  30000  rows
# CHUNK 605  has  30000  rows
# CHUNK 606  has  30000  rows
# CHUNK 607  has  30000  rows
# CHUNK 608  has  30000  rows
# CHUNK 609  has  30000  rows
# CHUNK 610  has  30000  rows
# CHUNK 611  has  30000  rows
# CHUNK 612  has  30000  rows
# CHUNK 613  has  30000  rows
# CHUNK 614  has  30000  rows
# CHUNK 615  has  30000  rows
# CHUNK 616  has  30000  rows
# CHUNK 617  has  30000  rows
# CHUNK 618  has  30000  rows
# CHUNK 619  has  30000  rows
# CHUNK 620  has  30000  rows
# took 1.290 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801023.raw
# CHUNK 621  has  30000  rows
# CHUNK 622  has  30000  rows
# CHUNK 623  has  30000  rows
# CHUNK 624  has  30000  rows
# CHUNK 625  has  30000  rows
# CHUNK 626  has  30000  rows
# CHUNK 627  has  30000  rows
# CHUNK 628  has  30000  rows
# CHUNK 629  has  30000  rows
# CHUNK 630  has  30000  rows
# CHUNK 631  has  30000  rows
# CHUNK 632  has  30000  rows
# CHUNK 633  has  30000  rows
# CHUNK 634  has  30000  rows
# CHUNK 635  has  30000  rows
# CHUNK 636  has  30000  rows
# CHUNK 637  has  30000  rows
# CHUNK 638  has  30000  rows
# CHUNK 639  has  30000  rows
# CHUNK 640  has  30000  rows
# CHUNK 641  has  30000  rows
# CHUNK 642  has  30000  rows
# CHUNK 643  has  30000  rows
# CHUNK 644  has  30000  rows
# CHUNK 645  has  30000  rows
# CHUNK 646  has  30000  rows
# CHUNK 647  has  30000  rows
# CHUNK 648  has  30000  rows
# CHUNK 649  has  30000  rows
# CHUNK 650  has  30000  rows
# CHUNK 651  has  30000  rows
# CHUNK 652  has  30000  rows
# CHUNK 653  has  30000  rows
# took 1.271 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801039.raw
# CHUNK 654  has  30000  rows
# CHUNK 655  has  30000  rows
# CHUNK 656  has  30000  rows
# CHUNK 657  has  30000  rows
# CHUNK 658  has  30000  rows
# CHUNK 659  has  30000  rows
# CHUNK 660  has  30000  rows
# CHUNK 661  has  30000  rows
# CHUNK 662  has  30000  rows
# CHUNK 663  has  30000  rows
# CHUNK 664  has  30000  rows
# CHUNK 665  has  30000  rows
# CHUNK 666  has  30000  rows
# CHUNK 667  has  30000  rows
# CHUNK 668  has  30000  rows
# CHUNK 669  has  30000  rows
# CHUNK 670  has  30000  rows
# CHUNK 671  has  30000  rows
# CHUNK 672  has  30000  rows
# CHUNK 673  has  30000  rows
# CHUNK 674  has  30000  rows
# CHUNK 675  has  30000  rows
# CHUNK 676  has  30000  rows
# CHUNK 677  has  30000  rows
# CHUNK 678  has  30000  rows
# CHUNK 679  has  30000  rows
# CHUNK 680  has  30000  rows
# CHUNK 681  has  30000  rows
# CHUNK 682  has  30000  rows
# CHUNK 683  has  30000  rows
# CHUNK 684  has  30000  rows
# CHUNK 685  has  30000  rows
# CHUNK 686  has  30000  rows
# CHUNK 687  has  30000  rows
# CHUNK 688  has  30000  rows
# CHUNK 689  has  30000  rows
# CHUNK 690  has  30000  rows
# CHUNK 691  has  30000  rows
# CHUNK 692  has  30000  rows
# CHUNK 693  has  30000  rows
# CHUNK 694  has  30000  rows
# CHUNK 695  has  30000  rows
# CHUNK 696  has  30000  rows
# CHUNK 697  has  30000  rows
# CHUNK 698  has  30000  rows
# CHUNK 699  has  30000  rows
# CHUNK 700  has  30000  rows
# CHUNK 701  has  30000  rows
# CHUNK 702  has  30000  rows
# CHUNK 703  has  30000  rows
# CHUNK 704  has  30000  rows
# CHUNK 705  has  30000  rows
# CHUNK 706  has  30000  rows
# CHUNK 707  has  30000  rows
# CHUNK 708  has  30000  rows
# CHUNK 709  has  30000  rows
# CHUNK 710  has  30000  rows
# CHUNK 711  has  30000  rows
# took 1.346 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801067.raw
# CHUNK 712  has  30000  rows
# CHUNK 713  has  30000  rows
# CHUNK 714  has  30000  rows
# CHUNK 715  has  30000  rows
# CHUNK 716  has  30000  rows
# CHUNK 717  has  30000  rows
# CHUNK 718  has  30000  rows
# CHUNK 719  has  30000  rows
# CHUNK 720  has  30000  rows
# CHUNK 721  has  30000  rows
# CHUNK 722  has  30000  rows
# CHUNK 723  has  30000  rows
# CHUNK 724  has  30000  rows
# CHUNK 725  has  30000  rows
# CHUNK 726  has  30000  rows
# CHUNK 727  has  30000  rows
# CHUNK 728  has  30000  rows
# CHUNK 729  has  30000  rows
# CHUNK 730  has  30000  rows
# CHUNK 731  has  30000  rows
# CHUNK 732  has  30000  rows
# CHUNK 733  has  30000  rows
# CHUNK 734  has  30000  rows
# CHUNK 735  has  30000  rows
# CHUNK 736  has  30000  rows
# CHUNK 737  has  30000  rows
# CHUNK 738  has  30000  rows
# CHUNK 739  has  30000  rows
# CHUNK 740  has  30000  rows
# CHUNK 741  has  30000  rows
# CHUNK 742  has  30000  rows
# CHUNK 743  has  30000  rows
# CHUNK 744  has  30000  rows
# took 1.271 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801084.raw
# CHUNK 745  has  30000  rows
# CHUNK 746  has  30000  rows
# CHUNK 747  has  30000  rows
# CHUNK 748  has  30000  rows
# CHUNK 749  has  30000  rows
# CHUNK 750  has  30000  rows
# CHUNK 751  has  30000  rows
# CHUNK 752  has  30000  rows
# CHUNK 753  has  30000  rows
# CHUNK 754  has  30000  rows
# CHUNK 755  has  30000  rows
# CHUNK 756  has  30000  rows
# CHUNK 757  has  30000  rows
# CHUNK 758  has  30000  rows
# CHUNK 759  has  30000  rows
# CHUNK 760  has  30000  rows
# CHUNK 761  has  30000  rows
# CHUNK 762  has  30000  rows
# CHUNK 763  has  30000  rows
# CHUNK 764  has  30000  rows
# CHUNK 765  has  30000  rows
# CHUNK 766  has  30000  rows
# CHUNK 767  has  30000  rows
# CHUNK 768  has  30000  rows
# CHUNK 769  has  30000  rows
# CHUNK 770  has  30000  rows
# CHUNK 771  has  30000  rows
# CHUNK 772  has  30000  rows
# CHUNK 773  has  30000  rows
# CHUNK 774  has  30000  rows
# CHUNK 775  has  30000  rows
# CHUNK 776  has  30000  rows
# CHUNK 777  has  30000  rows
# CHUNK 778  has  30000  rows
# CHUNK 779  has  30000  rows
# CHUNK 780  has  30000  rows
# CHUNK 781  has  30000  rows
# CHUNK 782  has  30000  rows
# CHUNK 783  has  30000  rows
# CHUNK 784  has  30000  rows
# CHUNK 785  has  30000  rows
# CHUNK 786  has  30000  rows
# CHUNK 787  has  30000  rows
# CHUNK 788  has  30000  rows
# CHUNK 789  has  30000  rows
# CHUNK 790  has  30000  rows
# CHUNK 791  has  30000  rows
# CHUNK 792  has  30000  rows
# CHUNK 793  has  30000  rows
# CHUNK 794  has  30000  rows
# CHUNK 795  has  30000  rows
# CHUNK 796  has  30000  rows
# CHUNK 797  has  30000  rows
# CHUNK 798  has  30000  rows
# CHUNK 799  has  30000  rows
# CHUNK 800  has  30000  rows
# CHUNK 801  has  30000  rows
# took 1.324 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801112.raw
# CHUNK 802  has  30000  rows
# CHUNK 803  has  30000  rows
# CHUNK 804  has  30000  rows
# CHUNK 805  has  30000  rows
# CHUNK 806  has  30000  rows
# CHUNK 807  has  30000  rows
# CHUNK 808  has  30000  rows
# CHUNK 809  has  30000  rows
# CHUNK 810  has  30000  rows
# CHUNK 811  has  30000  rows
# CHUNK 812  has  30000  rows
# CHUNK 813  has  30000  rows
# CHUNK 814  has  30000  rows
# CHUNK 815  has  30000  rows
# CHUNK 816  has  30000  rows
# CHUNK 817  has  30000  rows
# CHUNK 818  has  30000  rows
# CHUNK 819  has  30000  rows
# CHUNK 820  has  30000  rows
# CHUNK 821  has  30000  rows
# CHUNK 822  has  30000  rows
# CHUNK 823  has  30000  rows
# CHUNK 824  has  30000  rows
# CHUNK 825  has  30000  rows
# CHUNK 826  has  30000  rows
# CHUNK 827  has  30000  rows
# CHUNK 828  has  30000  rows
# CHUNK 829  has  30000  rows
# CHUNK 830  has  30000  rows
# CHUNK 831  has  30000  rows
# CHUNK 832  has  30000  rows
# CHUNK 833  has  30000  rows
# CHUNK 834  has  30000  rows
# took 1.326 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801128.raw
# CHUNK 835  has  30000  rows
# CHUNK 836  has  30000  rows
# CHUNK 837  has  30000  rows
# CHUNK 838  has  30000  rows
# CHUNK 839  has  30000  rows
# CHUNK 840  has  30000  rows
# CHUNK 841  has  30000  rows
# CHUNK 842  has  30000  rows
# CHUNK 843  has  30000  rows
# CHUNK 844  has  30000  rows
# CHUNK 845  has  30000  rows
# CHUNK 846  has  30000  rows
# CHUNK 847  has  30000  rows
# CHUNK 848  has  30000  rows
# CHUNK 849  has  30000  rows
# CHUNK 850  has  30000  rows
# CHUNK 851  has  30000  rows
# CHUNK 852  has  30000  rows
# CHUNK 853  has  30000  rows
# CHUNK 854  has  30000  rows
# CHUNK 855  has  30000  rows
# CHUNK 856  has  30000  rows
# CHUNK 857  has  30000  rows
# CHUNK 858  has  30000  rows
# CHUNK 859  has  30000  rows
# CHUNK 860  has  30000  rows
# CHUNK 861  has  30000  rows
# CHUNK 862  has  30000  rows
# CHUNK 863  has  30000  rows
# CHUNK 864  has  30000  rows
# CHUNK 865  has  30000  rows
# CHUNK 866  has  30000  rows
# CHUNK 867  has  30000  rows
# CHUNK 868  has  30000  rows
# CHUNK 869  has  30000  rows
# CHUNK 870  has  30000  rows
# CHUNK 871  has  30000  rows
# CHUNK 872  has  30000  rows
# CHUNK 873  has  30000  rows
# CHUNK 874  has  30000  rows
# CHUNK 875  has  30000  rows
# CHUNK 876  has  30000  rows
# CHUNK 877  has  30000  rows
# CHUNK 878  has  30000  rows
# CHUNK 879  has  30000  rows
# CHUNK 880  has  30000  rows
# CHUNK 881  has  30000  rows
# CHUNK 882  has  30000  rows
# CHUNK 883  has  30000  rows
# CHUNK 884  has  30000  rows
# CHUNK 885  has  30000  rows
# CHUNK 886  has  30000  rows
# CHUNK 887  has  30000  rows
# CHUNK 888  has  30000  rows
# CHUNK 889  has  30000  rows
# CHUNK 890  has  30000  rows
# CHUNK 891  has  30000  rows
# took 1.308 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801156.raw
# CHUNK 892  has  30000  rows
# CHUNK 893  has  30000  rows
# CHUNK 894  has  30000  rows
# CHUNK 895  has  30000  rows
# CHUNK 896  has  30000  rows
# CHUNK 897  has  30000  rows
# CHUNK 898  has  30000  rows
# CHUNK 899  has  30000  rows
# CHUNK 900  has  30000  rows
# CHUNK 901  has  30000  rows
# CHUNK 902  has  30000  rows
# CHUNK 903  has  30000  rows
# CHUNK 904  has  30000  rows
# CHUNK 905  has  30000  rows
# CHUNK 906  has  30000  rows
# CHUNK 907  has  30000  rows
# CHUNK 908  has  30000  rows
# CHUNK 909  has  30000  rows
# CHUNK 910  has  30000  rows
# CHUNK 911  has  30000  rows
# CHUNK 912  has  30000  rows
# CHUNK 913  has  30000  rows
# CHUNK 914  has  30000  rows
# CHUNK 915  has  30000  rows
# CHUNK 916  has  30000  rows
# CHUNK 917  has  30000  rows
# CHUNK 918  has  30000  rows
# CHUNK 919  has  30000  rows
# CHUNK 920  has  30000  rows
# CHUNK 921  has  30000  rows
# CHUNK 922  has  30000  rows
# CHUNK 923  has  30000  rows
# CHUNK 924  has  30000  rows
# took 1.308 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801172.raw
# CHUNK 925  has  30000  rows
# CHUNK 926  has  30000  rows
# CHUNK 927  has  30000  rows
# CHUNK 928  has  30000  rows
# CHUNK 929  has  30000  rows
# CHUNK 930  has  30000  rows
# CHUNK 931  has  30000  rows
# CHUNK 932  has  30000  rows
# CHUNK 933  has  30000  rows
# CHUNK 934  has  30000  rows
# CHUNK 935  has  30000  rows
# CHUNK 936  has  30000  rows
# CHUNK 937  has  30000  rows
# CHUNK 938  has  30000  rows
# CHUNK 939  has  30000  rows
# CHUNK 940  has  30000  rows
# CHUNK 941  has  30000  rows
# CHUNK 942  has  30000  rows
# CHUNK 943  has  30000  rows
# CHUNK 944  has  30000  rows
# CHUNK 945  has  30000  rows
# CHUNK 946  has  30000  rows
# CHUNK 947  has  30000  rows
# CHUNK 948  has  30000  rows
# CHUNK 949  has  30000  rows
# CHUNK 950  has  30000  rows
# CHUNK 951  has  30000  rows
# CHUNK 952  has  30000  rows
# CHUNK 953  has  30000  rows
# CHUNK 954  has  30000  rows
# CHUNK 955  has  30000  rows
# CHUNK 956  has  30000  rows
# CHUNK 957  has  30000  rows
# CHUNK 958  has  30000  rows
# CHUNK 959  has  30000  rows
# CHUNK 960  has  30000  rows
# CHUNK 961  has  30000  rows
# CHUNK 962  has  30000  rows
# CHUNK 963  has  30000  rows
# CHUNK 964  has  30000  rows
# CHUNK 965  has  30000  rows
# CHUNK 966  has  30000  rows
# CHUNK 967  has  30000  rows
# CHUNK 968  has  30000  rows
# CHUNK 969  has  30000  rows
# CHUNK 970  has  30000  rows
# CHUNK 971  has  30000  rows
# CHUNK 972  has  30000  rows
# CHUNK 973  has  30000  rows
# CHUNK 974  has  30000  rows
# CHUNK 975  has  30000  rows
# CHUNK 976  has  30000  rows
# CHUNK 977  has  30000  rows
# CHUNK 978  has  30000  rows
# CHUNK 979  has  30000  rows
# CHUNK 980  has  30000  rows
# CHUNK 981  has  30000  rows
# CHUNK 982  has  30000  rows
# took 1.308 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801201.raw
# CHUNK 983  has  30000  rows
# CHUNK 984  has  30000  rows
# CHUNK 985  has  30000  rows
# CHUNK 986  has  30000  rows
# CHUNK 987  has  30000  rows
# CHUNK 988  has  30000  rows
# CHUNK 989  has  30000  rows
# CHUNK 990  has  30000  rows
# CHUNK 991  has  30000  rows
# CHUNK 992  has  30000  rows
# CHUNK 993  has  30000  rows
# CHUNK 994  has  30000  rows
# CHUNK 995  has  30000  rows
# CHUNK 996  has  30000  rows
# CHUNK 997  has  30000  rows
# CHUNK 998  has  30000  rows
# CHUNK 999  has  30000  rows
# CHUNK 1000  has  30000  rows
# CHUNK 1001  has  30000  rows
# CHUNK 1002  has  30000  rows
# CHUNK 1003  has  30000  rows
# CHUNK 1004  has  30000  rows
# CHUNK 1005  has  30000  rows
# CHUNK 1006  has  30000  rows
# CHUNK 1007  has  30000  rows
# CHUNK 1008  has  30000  rows
# CHUNK 1009  has  30000  rows
# CHUNK 1010  has  30000  rows
# CHUNK 1011  has  30000  rows
# CHUNK 1012  has  30000  rows
# CHUNK 1013  has  30000  rows
# CHUNK 1014  has  30000  rows
# CHUNK 1015  has  30000  rows
# took 1.266 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801217.raw
# CHUNK 1016  has  30000  rows
# CHUNK 1017  has  30000  rows
# CHUNK 1018  has  30000  rows
# CHUNK 1019  has  30000  rows
# CHUNK 1020  has  30000  rows
# CHUNK 1021  has  30000  rows
# CHUNK 1022  has  30000  rows
# CHUNK 1023  has  30000  rows
# CHUNK 1024  has  30000  rows
# CHUNK 1025  has  30000  rows
# CHUNK 1026  has  30000  rows
# CHUNK 1027  has  30000  rows
# CHUNK 1028  has  30000  rows
# CHUNK 1029  has  30000  rows
# CHUNK 1030  has  30000  rows
# CHUNK 1031  has  30000  rows
# CHUNK 1032  has  30000  rows
# CHUNK 1033  has  30000  rows
# CHUNK 1034  has  30000  rows
# CHUNK 1035  has  30000  rows
# CHUNK 1036  has  30000  rows
# CHUNK 1037  has  30000  rows
# CHUNK 1038  has  30000  rows
# CHUNK 1039  has  30000  rows
# CHUNK 1040  has  30000  rows
# CHUNK 1041  has  30000  rows
# CHUNK 1042  has  30000  rows
# CHUNK 1043  has  30000  rows
# CHUNK 1044  has  30000  rows
# CHUNK 1045  has  30000  rows
# CHUNK 1046  has  30000  rows
# CHUNK 1047  has  30000  rows
# CHUNK 1048  has  30000  rows
# CHUNK 1049  has  30000  rows
# CHUNK 1050  has  30000  rows
# CHUNK 1051  has  30000  rows
# CHUNK 1052  has  30000  rows
# CHUNK 1053  has  30000  rows
# CHUNK 1054  has  30000  rows
# CHUNK 1055  has  30000  rows
# CHUNK 1056  has  30000  rows
# CHUNK 1057  has  30000  rows
# CHUNK 1058  has  30000  rows
# CHUNK 1059  has  30000  rows
# CHUNK 1060  has  30000  rows
# CHUNK 1061  has  30000  rows
# CHUNK 1062  has  30000  rows
# CHUNK 1063  has  30000  rows
# CHUNK 1064  has  30000  rows
# CHUNK 1065  has  30000  rows
# CHUNK 1066  has  30000  rows
# CHUNK 1067  has  30000  rows
# CHUNK 1068  has  30000  rows
# CHUNK 1069  has  30000  rows
# CHUNK 1070  has  30000  rows
# CHUNK 1071  has  30000  rows
# CHUNK 1072  has  30000  rows
# took 1.337 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801245.raw
# CHUNK 1073  has  30000  rows
# CHUNK 1074  has  30000  rows
# CHUNK 1075  has  30000  rows
# CHUNK 1076  has  30000  rows
# CHUNK 1077  has  30000  rows
# CHUNK 1078  has  30000  rows
# CHUNK 1079  has  30000  rows
# CHUNK 1080  has  30000  rows
# CHUNK 1081  has  30000  rows
# CHUNK 1082  has  30000  rows
# CHUNK 1083  has  30000  rows
# CHUNK 1084  has  30000  rows
# CHUNK 1085  has  30000  rows
# CHUNK 1086  has  30000  rows
# CHUNK 1087  has  30000  rows
# CHUNK 1088  has  30000  rows
# CHUNK 1089  has  30000  rows
# CHUNK 1090  has  30000  rows
# CHUNK 1091  has  30000  rows
# CHUNK 1092  has  30000  rows
# CHUNK 1093  has  30000  rows
# CHUNK 1094  has  30000  rows
# CHUNK 1095  has  30000  rows
# CHUNK 1096  has  30000  rows
# CHUNK 1097  has  30000  rows
# CHUNK 1098  has  30000  rows
# CHUNK 1099  has  30000  rows
# CHUNK 1100  has  30000  rows
# CHUNK 1101  has  30000  rows
# CHUNK 1102  has  30000  rows
# CHUNK 1103  has  30000  rows
# CHUNK 1104  has  30000  rows
# CHUNK 1105  has  30000  rows
# took 1.330 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801261.raw
# CHUNK 1106  has  30000  rows
# CHUNK 1107  has  30000  rows
# CHUNK 1108  has  30000  rows
# CHUNK 1109  has  30000  rows
# CHUNK 1110  has  30000  rows
# CHUNK 1111  has  30000  rows
# CHUNK 1112  has  30000  rows
# CHUNK 1113  has  30000  rows
# CHUNK 1114  has  30000  rows
# CHUNK 1115  has  30000  rows
# CHUNK 1116  has  30000  rows
# CHUNK 1117  has  30000  rows
# CHUNK 1118  has  30000  rows
# CHUNK 1119  has  30000  rows
# CHUNK 1120  has  30000  rows
# CHUNK 1121  has  30000  rows
# CHUNK 1122  has  30000  rows
# CHUNK 1123  has  30000  rows
# CHUNK 1124  has  30000  rows
# CHUNK 1125  has  30000  rows
# CHUNK 1126  has  30000  rows
# CHUNK 1127  has  30000  rows
# CHUNK 1128  has  30000  rows
# CHUNK 1129  has  30000  rows
# CHUNK 1130  has  30000  rows
# CHUNK 1131  has  30000  rows
# CHUNK 1132  has  30000  rows
# CHUNK 1133  has  30000  rows
# CHUNK 1134  has  30000  rows
# CHUNK 1135  has  30000  rows
# CHUNK 1136  has  30000  rows
# CHUNK 1137  has  30000  rows
# CHUNK 1138  has  30000  rows
# CHUNK 1139  has  30000  rows
# CHUNK 1140  has  30000  rows
# CHUNK 1141  has  30000  rows
# CHUNK 1142  has  30000  rows
# CHUNK 1143  has  30000  rows
# CHUNK 1144  has  30000  rows
# CHUNK 1145  has  30000  rows
# CHUNK 1146  has  30000  rows
# CHUNK 1147  has  30000  rows
# CHUNK 1148  has  30000  rows
# CHUNK 1149  has  30000  rows
# CHUNK 1150  has  30000  rows
# CHUNK 1151  has  30000  rows
# CHUNK 1152  has  30000  rows
# CHUNK 1153  has  30000  rows
# CHUNK 1154  has  30000  rows
# CHUNK 1155  has  30000  rows
# CHUNK 1156  has  30000  rows
# CHUNK 1157  has  30000  rows
# CHUNK 1158  has  30000  rows
# CHUNK 1159  has  30000  rows
# CHUNK 1160  has  30000  rows
# CHUNK 1161  has  30000  rows
# CHUNK 1162  has  30000  rows
# took 1.310 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801289.raw
# CHUNK 1163  has  30000  rows
# CHUNK 1164  has  30000  rows
# CHUNK 1165  has  30000  rows
# CHUNK 1166  has  30000  rows
# CHUNK 1167  has  30000  rows
# CHUNK 1168  has  30000  rows
# CHUNK 1169  has  30000  rows
# CHUNK 1170  has  30000  rows
# CHUNK 1171  has  30000  rows
# CHUNK 1172  has  30000  rows
# CHUNK 1173  has  30000  rows
# CHUNK 1174  has  30000  rows
# CHUNK 1175  has  30000  rows
# CHUNK 1176  has  30000  rows
# CHUNK 1177  has  30000  rows
# CHUNK 1178  has  30000  rows
# CHUNK 1179  has  30000  rows
# CHUNK 1180  has  30000  rows
# CHUNK 1181  has  30000  rows
# CHUNK 1182  has  30000  rows
# CHUNK 1183  has  30000  rows
# CHUNK 1184  has  30000  rows
# CHUNK 1185  has  30000  rows
# CHUNK 1186  has  30000  rows
# CHUNK 1187  has  30000  rows
# CHUNK 1188  has  30000  rows
# CHUNK 1189  has  30000  rows
# CHUNK 1190  has  30000  rows
# CHUNK 1191  has  30000  rows
# CHUNK 1192  has  30000  rows
# CHUNK 1193  has  30000  rows
# CHUNK 1194  has  30000  rows
# CHUNK 1195  has  30000  rows
# took 1.305 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801306.raw
# CHUNK 1196  has  30000  rows
# CHUNK 1197  has  30000  rows
# CHUNK 1198  has  30000  rows
# CHUNK 1199  has  30000  rows
# CHUNK 1200  has  30000  rows
# CHUNK 1201  has  30000  rows
# CHUNK 1202  has  30000  rows
# CHUNK 1203  has  30000  rows
# CHUNK 1204  has  30000  rows
# CHUNK 1205  has  30000  rows
# CHUNK 1206  has  30000  rows
# CHUNK 1207  has  30000  rows
# CHUNK 1208  has  30000  rows
# CHUNK 1209  has  30000  rows
# CHUNK 1210  has  30000  rows
# CHUNK 1211  has  30000  rows
# CHUNK 1212  has  30000  rows
# CHUNK 1213  has  30000  rows
# CHUNK 1214  has  30000  rows
# CHUNK 1215  has  30000  rows
# CHUNK 1216  has  30000  rows
# CHUNK 1217  has  30000  rows
# CHUNK 1218  has  30000  rows
# CHUNK 1219  has  30000  rows
# CHUNK 1220  has  30000  rows
# CHUNK 1221  has  30000  rows
# CHUNK 1222  has  30000  rows
# CHUNK 1223  has  30000  rows
# CHUNK 1224  has  30000  rows
# CHUNK 1225  has  30000  rows
# CHUNK 1226  has  30000  rows
# CHUNK 1227  has  30000  rows
# CHUNK 1228  has  30000  rows
# CHUNK 1229  has  30000  rows
# CHUNK 1230  has  30000  rows
# CHUNK 1231  has  30000  rows
# CHUNK 1232  has  30000  rows
# CHUNK 1233  has  30000  rows
# CHUNK 1234  has  30000  rows
# CHUNK 1235  has  30000  rows
# CHUNK 1236  has  30000  rows
# CHUNK 1237  has  30000  rows
# CHUNK 1238  has  30000  rows
# CHUNK 1239  has  30000  rows
# CHUNK 1240  has  30000  rows
# CHUNK 1241  has  30000  rows
# CHUNK 1242  has  30000  rows
# CHUNK 1243  has  30000  rows
# CHUNK 1244  has  30000  rows
# CHUNK 1245  has  30000  rows
# CHUNK 1246  has  30000  rows
# CHUNK 1247  has  30000  rows
# CHUNK 1248  has  30000  rows
# CHUNK 1249  has  30000  rows
# CHUNK 1250  has  30000  rows
# CHUNK 1251  has  30000  rows
# CHUNK 1252  has  30000  rows
# CHUNK 1253  has  30000  rows
# took 1.247 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801334.raw
# CHUNK 1254  has  30000  rows
# CHUNK 1255  has  30000  rows
# CHUNK 1256  has  30000  rows
# CHUNK 1257  has  30000  rows
# CHUNK 1258  has  30000  rows
# CHUNK 1259  has  30000  rows
# CHUNK 1260  has  30000  rows
# CHUNK 1261  has  30000  rows
# CHUNK 1262  has  30000  rows
# CHUNK 1263  has  30000  rows
# CHUNK 1264  has  30000  rows
# CHUNK 1265  has  30000  rows
# CHUNK 1266  has  30000  rows
# CHUNK 1267  has  30000  rows
# CHUNK 1268  has  30000  rows
# CHUNK 1269  has  30000  rows
# CHUNK 1270  has  30000  rows
# CHUNK 1271  has  30000  rows
# CHUNK 1272  has  30000  rows
# CHUNK 1273  has  30000  rows
# CHUNK 1274  has  30000  rows
# CHUNK 1275  has  30000  rows
# CHUNK 1276  has  30000  rows
# CHUNK 1277  has  30000  rows
# CHUNK 1278  has  30000  rows
# CHUNK 1279  has  30000  rows
# CHUNK 1280  has  30000  rows
# CHUNK 1281  has  30000  rows
# CHUNK 1282  has  30000  rows
# CHUNK 1283  has  30000  rows
# CHUNK 1284  has  30000  rows
# CHUNK 1285  has  30000  rows
# took 1.342 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801350.raw
# CHUNK 1286  has  30000  rows
# CHUNK 1287  has  30000  rows
# CHUNK 1288  has  30000  rows
# CHUNK 1289  has  30000  rows
# CHUNK 1290  has  30000  rows
# CHUNK 1291  has  30000  rows
# CHUNK 1292  has  30000  rows
# CHUNK 1293  has  30000  rows
# CHUNK 1294  has  30000  rows
# CHUNK 1295  has  30000  rows
# CHUNK 1296  has  30000  rows
# CHUNK 1297  has  30000  rows
# CHUNK 1298  has  30000  rows
# CHUNK 1299  has  30000  rows
# CHUNK 1300  has  30000  rows
# CHUNK 1301  has  30000  rows
# CHUNK 1302  has  30000  rows
# CHUNK 1303  has  30000  rows
# CHUNK 1304  has  30000  rows
# CHUNK 1305  has  30000  rows
# CHUNK 1306  has  30000  rows
# CHUNK 1307  has  30000  rows
# CHUNK 1308  has  30000  rows
# CHUNK 1309  has  30000  rows
# CHUNK 1310  has  30000  rows
# CHUNK 1311  has  30000  rows
# CHUNK 1312  has  30000  rows
# CHUNK 1313  has  30000  rows
# CHUNK 1314  has  30000  rows
# CHUNK 1315  has  30000  rows
# CHUNK 1316  has  30000  rows
# CHUNK 1317  has  30000  rows
# CHUNK 1318  has  30000  rows
# CHUNK 1319  has  30000  rows
# CHUNK 1320  has  30000  rows
# CHUNK 1321  has  30000  rows
# CHUNK 1322  has  30000  rows
# CHUNK 1323  has  30000  rows
# CHUNK 1324  has  30000  rows
# CHUNK 1325  has  30000  rows
# CHUNK 1326  has  30000  rows
# CHUNK 1327  has  30000  rows
# CHUNK 1328  has  30000  rows
# CHUNK 1329  has  30000  rows
# CHUNK 1330  has  30000  rows
# CHUNK 1331  has  30000  rows
# CHUNK 1332  has  30000  rows
# CHUNK 1333  has  30000  rows
# CHUNK 1334  has  30000  rows
# CHUNK 1335  has  30000  rows
# CHUNK 1336  has  30000  rows
# CHUNK 1337  has  30000  rows
# CHUNK 1338  has  30000  rows
# CHUNK 1339  has  30000  rows
# CHUNK 1340  has  30000  rows
# CHUNK 1341  has  30000  rows
# CHUNK 1342  has  30000  rows
# CHUNK 1343  has  30000  rows
# took 1.338 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801378.raw
# CHUNK 1344  has  30000  rows
# CHUNK 1345  has  30000  rows
# CHUNK 1346  has  30000  rows
# CHUNK 1347  has  30000  rows
# CHUNK 1348  has  30000  rows
# CHUNK 1349  has  30000  rows
# CHUNK 1350  has  30000  rows
# CHUNK 1351  has  30000  rows
# CHUNK 1352  has  30000  rows
# CHUNK 1353  has  30000  rows
# CHUNK 1354  has  30000  rows
# CHUNK 1355  has  30000  rows
# CHUNK 1356  has  30000  rows
# CHUNK 1357  has  30000  rows
# CHUNK 1358  has  30000  rows
# CHUNK 1359  has  30000  rows
# CHUNK 1360  has  30000  rows
# CHUNK 1361  has  30000  rows
# CHUNK 1362  has  30000  rows
# CHUNK 1363  has  30000  rows
# CHUNK 1364  has  30000  rows
# CHUNK 1365  has  30000  rows
# CHUNK 1366  has  30000  rows
# CHUNK 1367  has  30000  rows
# CHUNK 1368  has  30000  rows
# CHUNK 1369  has  30000  rows
# CHUNK 1370  has  30000  rows
# CHUNK 1371  has  30000  rows
# CHUNK 1372  has  30000  rows
# CHUNK 1373  has  30000  rows
# CHUNK 1374  has  30000  rows
# CHUNK 1375  has  30000  rows
# CHUNK 1376  has  30000  rows
# took 1.311 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801394.raw
# CHUNK 1377  has  30000  rows
# CHUNK 1378  has  30000  rows
# CHUNK 1379  has  30000  rows
# CHUNK 1380  has  30000  rows
# CHUNK 1381  has  30000  rows
# CHUNK 1382  has  30000  rows
# CHUNK 1383  has  30000  rows
# CHUNK 1384  has  30000  rows
# CHUNK 1385  has  30000  rows
# CHUNK 1386  has  30000  rows
# CHUNK 1387  has  30000  rows
# CHUNK 1388  has  30000  rows
# CHUNK 1389  has  30000  rows
# CHUNK 1390  has  30000  rows
# CHUNK 1391  has  30000  rows
# CHUNK 1392  has  30000  rows
# CHUNK 1393  has  30000  rows
# CHUNK 1394  has  30000  rows
# CHUNK 1395  has  30000  rows
# CHUNK 1396  has  30000  rows
# CHUNK 1397  has  30000  rows
# CHUNK 1398  has  30000  rows
# CHUNK 1399  has  30000  rows
# CHUNK 1400  has  30000  rows
# CHUNK 1401  has  30000  rows
# CHUNK 1402  has  30000  rows
# CHUNK 1403  has  30000  rows
# CHUNK 1404  has  30000  rows
# CHUNK 1405  has  30000  rows
# CHUNK 1406  has  30000  rows
# CHUNK 1407  has  30000  rows
# CHUNK 1408  has  30000  rows
# CHUNK 1409  has  30000  rows
# CHUNK 1410  has  30000  rows
# CHUNK 1411  has  30000  rows
# CHUNK 1412  has  30000  rows
# CHUNK 1413  has  30000  rows
# CHUNK 1414  has  30000  rows
# CHUNK 1415  has  30000  rows
# CHUNK 1416  has  30000  rows
# CHUNK 1417  has  30000  rows
# CHUNK 1418  has  30000  rows
# CHUNK 1419  has  30000  rows
# CHUNK 1420  has  30000  rows
# CHUNK 1421  has  30000  rows
# CHUNK 1422  has  30000  rows
# CHUNK 1423  has  30000  rows
# CHUNK 1424  has  30000  rows
# CHUNK 1425  has  30000  rows
# CHUNK 1426  has  30000  rows
# CHUNK 1427  has  30000  rows
# CHUNK 1428  has  30000  rows
# CHUNK 1429  has  30000  rows
# CHUNK 1430  has  30000  rows
# CHUNK 1431  has  30000  rows
# CHUNK 1432  has  30000  rows
# CHUNK 1433  has  30000  rows
# took 1.353 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801423.raw
# CHUNK 1434  has  30000  rows
# CHUNK 1435  has  30000  rows
# CHUNK 1436  has  30000  rows
# CHUNK 1437  has  30000  rows
# CHUNK 1438  has  30000  rows
# CHUNK 1439  has  30000  rows
# CHUNK 1440  has  30000  rows
# CHUNK 1441  has  30000  rows
# CHUNK 1442  has  30000  rows
# CHUNK 1443  has  30000  rows
# CHUNK 1444  has  30000  rows
# CHUNK 1445  has  30000  rows
# CHUNK 1446  has  30000  rows
# CHUNK 1447  has  30000  rows
# CHUNK 1448  has  30000  rows
# CHUNK 1449  has  30000  rows
# CHUNK 1450  has  30000  rows
# CHUNK 1451  has  30000  rows
# CHUNK 1452  has  30000  rows
# CHUNK 1453  has  30000  rows
# CHUNK 1454  has  30000  rows
# CHUNK 1455  has  30000  rows
# CHUNK 1456  has  30000  rows
# CHUNK 1457  has  30000  rows
# CHUNK 1458  has  30000  rows
# CHUNK 1459  has  30000  rows
# CHUNK 1460  has  30000  rows
# CHUNK 1461  has  30000  rows
# CHUNK 1462  has  30000  rows
# CHUNK 1463  has  30000  rows
# CHUNK 1464  has  30000  rows
# CHUNK 1465  has  30000  rows
# CHUNK 1466  has  30000  rows
# took 1.309 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801439.raw
# CHUNK 1467  has  30000  rows
# CHUNK 1468  has  30000  rows
# CHUNK 1469  has  30000  rows
# CHUNK 1470  has  30000  rows
# CHUNK 1471  has  30000  rows
# CHUNK 1472  has  30000  rows
# CHUNK 1473  has  30000  rows
# CHUNK 1474  has  30000  rows
# CHUNK 1475  has  30000  rows
# CHUNK 1476  has  30000  rows
# CHUNK 1477  has  30000  rows
# CHUNK 1478  has  30000  rows
# CHUNK 1479  has  30000  rows
# CHUNK 1480  has  30000  rows
# CHUNK 1481  has  30000  rows
# CHUNK 1482  has  30000  rows
# CHUNK 1483  has  30000  rows
# CHUNK 1484  has  30000  rows
# CHUNK 1485  has  30000  rows
# CHUNK 1486  has  30000  rows
# CHUNK 1487  has  30000  rows
# CHUNK 1488  has  30000  rows
# CHUNK 1489  has  30000  rows
# CHUNK 1490  has  30000  rows
# CHUNK 1491  has  30000  rows
# CHUNK 1492  has  30000  rows
# CHUNK 1493  has  30000  rows
# CHUNK 1494  has  30000  rows
# CHUNK 1495  has  30000  rows
# CHUNK 1496  has  30000  rows
# CHUNK 1497  has  30000  rows
# CHUNK 1498  has  30000  rows
# CHUNK 1499  has  30000  rows
# CHUNK 1500  has  30000  rows
# CHUNK 1501  has  30000  rows
# CHUNK 1502  has  30000  rows
# CHUNK 1503  has  30000  rows
# CHUNK 1504  has  30000  rows
# CHUNK 1505  has  30000  rows
# CHUNK 1506  has  30000  rows
# CHUNK 1507  has  30000  rows
# CHUNK 1508  has  30000  rows
# CHUNK 1509  has  30000  rows
# CHUNK 1510  has  30000  rows
# CHUNK 1511  has  30000  rows
# CHUNK 1512  has  30000  rows
# CHUNK 1513  has  30000  rows
# CHUNK 1514  has  30000  rows
# CHUNK 1515  has  30000  rows
# CHUNK 1516  has  30000  rows
# CHUNK 1517  has  30000  rows
# CHUNK 1518  has  30000  rows
# CHUNK 1519  has  30000  rows
# CHUNK 1520  has  30000  rows
# CHUNK 1521  has  30000  rows
# CHUNK 1522  has  30000  rows
# CHUNK 1523  has  30000  rows
# took 1.293 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801467.raw
# CHUNK 1524  has  30000  rows
# CHUNK 1525  has  30000  rows
# CHUNK 1526  has  30000  rows
# CHUNK 1527  has  30000  rows
# CHUNK 1528  has  30000  rows
# CHUNK 1529  has  30000  rows
# CHUNK 1530  has  30000  rows
# CHUNK 1531  has  30000  rows
# CHUNK 1532  has  30000  rows
# CHUNK 1533  has  30000  rows
# CHUNK 1534  has  30000  rows
# CHUNK 1535  has  30000  rows
# CHUNK 1536  has  30000  rows
# CHUNK 1537  has  30000  rows
# CHUNK 1538  has  30000  rows
# CHUNK 1539  has  30000  rows
# CHUNK 1540  has  30000  rows
# CHUNK 1541  has  30000  rows
# CHUNK 1542  has  30000  rows
# CHUNK 1543  has  30000  rows
# CHUNK 1544  has  30000  rows
# CHUNK 1545  has  30000  rows
# CHUNK 1546  has  30000  rows
# CHUNK 1547  has  30000  rows
# CHUNK 1548  has  30000  rows
# CHUNK 1549  has  30000  rows
# CHUNK 1550  has  30000  rows
# CHUNK 1551  has  30000  rows
# CHUNK 1552  has  30000  rows
# CHUNK 1553  has  30000  rows
# CHUNK 1554  has  30000  rows
# CHUNK 1555  has  30000  rows
# CHUNK 1556  has  30000  rows
# took 1.268 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801483.raw
# CHUNK 1557  has  30000  rows
# CHUNK 1558  has  30000  rows
# CHUNK 1559  has  30000  rows
# CHUNK 1560  has  30000  rows
# CHUNK 1561  has  30000  rows
# CHUNK 1562  has  30000  rows
# CHUNK 1563  has  30000  rows
# CHUNK 1564  has  30000  rows
# CHUNK 1565  has  30000  rows
# CHUNK 1566  has  30000  rows
# CHUNK 1567  has  30000  rows
# CHUNK 1568  has  30000  rows
# CHUNK 1569  has  30000  rows
# CHUNK 1570  has  30000  rows
# CHUNK 1571  has  30000  rows
# CHUNK 1572  has  30000  rows
# CHUNK 1573  has  30000  rows
# CHUNK 1574  has  30000  rows
# CHUNK 1575  has  30000  rows
# CHUNK 1576  has  30000  rows
# CHUNK 1577  has  30000  rows
# CHUNK 1578  has  30000  rows
# CHUNK 1579  has  30000  rows
# CHUNK 1580  has  30000  rows
# CHUNK 1581  has  30000  rows
# CHUNK 1582  has  30000  rows
# CHUNK 1583  has  30000  rows
# CHUNK 1584  has  30000  rows
# CHUNK 1585  has  30000  rows
# CHUNK 1586  has  30000  rows
# CHUNK 1587  has  30000  rows
# CHUNK 1588  has  30000  rows
# CHUNK 1589  has  30000  rows
# CHUNK 1590  has  30000  rows
# CHUNK 1591  has  30000  rows
# CHUNK 1592  has  30000  rows
# CHUNK 1593  has  30000  rows
# CHUNK 1594  has  30000  rows
# CHUNK 1595  has  30000  rows
# CHUNK 1596  has  30000  rows
# CHUNK 1597  has  30000  rows
# CHUNK 1598  has  30000  rows
# CHUNK 1599  has  30000  rows
# CHUNK 1600  has  30000  rows
# CHUNK 1601  has  30000  rows
# CHUNK 1602  has  30000  rows
# CHUNK 1603  has  30000  rows
# CHUNK 1604  has  30000  rows
# CHUNK 1605  has  30000  rows
# CHUNK 1606  has  30000  rows
# CHUNK 1607  has  30000  rows
# CHUNK 1608  has  30000  rows
# CHUNK 1609  has  30000  rows
# CHUNK 1610  has  30000  rows
# CHUNK 1611  has  30000  rows
# CHUNK 1612  has  30000  rows
# CHUNK 1613  has  30000  rows
# CHUNK 1614  has  30000  rows
# took 1.355 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801511.raw
# CHUNK 1615  has  30000  rows
# CHUNK 1616  has  30000  rows
# CHUNK 1617  has  30000  rows
# CHUNK 1618  has  30000  rows
# CHUNK 1619  has  30000  rows
# CHUNK 1620  has  30000  rows
# CHUNK 1621  has  30000  rows
# CHUNK 1622  has  30000  rows
# CHUNK 1623  has  30000  rows
# CHUNK 1624  has  30000  rows
# CHUNK 1625  has  30000  rows
# CHUNK 1626  has  30000  rows
# CHUNK 1627  has  30000  rows
# CHUNK 1628  has  30000  rows
# CHUNK 1629  has  30000  rows
# CHUNK 1630  has  30000  rows
# CHUNK 1631  has  30000  rows
# CHUNK 1632  has  30000  rows
# CHUNK 1633  has  30000  rows
# CHUNK 1634  has  30000  rows
# CHUNK 1635  has  30000  rows
# CHUNK 1636  has  30000  rows
# CHUNK 1637  has  30000  rows
# CHUNK 1638  has  30000  rows
# CHUNK 1639  has  30000  rows
# CHUNK 1640  has  30000  rows
# CHUNK 1641  has  30000  rows
# CHUNK 1642  has  30000  rows
# CHUNK 1643  has  30000  rows
# CHUNK 1644  has  30000  rows
# CHUNK 1645  has  30000  rows
# CHUNK 1646  has  30000  rows
# CHUNK 1647  has  30000  rows
# took 1.288 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801527.raw
# CHUNK 1648  has  30000  rows
# CHUNK 1649  has  30000  rows
# CHUNK 1650  has  30000  rows
# CHUNK 1651  has  30000  rows
# CHUNK 1652  has  30000  rows
# CHUNK 1653  has  30000  rows
# CHUNK 1654  has  30000  rows
# CHUNK 1655  has  30000  rows
# CHUNK 1656  has  30000  rows
# CHUNK 1657  has  30000  rows
# CHUNK 1658  has  30000  rows
# CHUNK 1659  has  30000  rows
# CHUNK 1660  has  30000  rows
# CHUNK 1661  has  30000  rows
# CHUNK 1662  has  30000  rows
# CHUNK 1663  has  30000  rows
# CHUNK 1664  has  30000  rows
# CHUNK 1665  has  30000  rows
# CHUNK 1666  has  30000  rows
# CHUNK 1667  has  30000  rows
# CHUNK 1668  has  30000  rows
# CHUNK 1669  has  30000  rows
# CHUNK 1670  has  30000  rows
# CHUNK 1671  has  30000  rows
# CHUNK 1672  has  30000  rows
# CHUNK 1673  has  30000  rows
# CHUNK 1674  has  30000  rows
# CHUNK 1675  has  30000  rows
# CHUNK 1676  has  30000  rows
# CHUNK 1677  has  30000  rows
# CHUNK 1678  has  30000  rows
# CHUNK 1679  has  30000  rows
# CHUNK 1680  has  30000  rows
# CHUNK 1681  has  30000  rows
# CHUNK 1682  has  30000  rows
# CHUNK 1683  has  30000  rows
# CHUNK 1684  has  30000  rows
# CHUNK 1685  has  30000  rows
# CHUNK 1686  has  30000  rows
# CHUNK 1687  has  30000  rows
# CHUNK 1688  has  30000  rows
# CHUNK 1689  has  30000  rows
# CHUNK 1690  has  30000  rows
# CHUNK 1691  has  30000  rows
# CHUNK 1692  has  30000  rows
# CHUNK 1693  has  30000  rows
# CHUNK 1694  has  30000  rows
# CHUNK 1695  has  30000  rows
# CHUNK 1696  has  30000  rows
# CHUNK 1697  has  30000  rows
# CHUNK 1698  has  30000  rows
# CHUNK 1699  has  30000  rows
# CHUNK 1700  has  30000  rows
# CHUNK 1701  has  30000  rows
# CHUNK 1702  has  30000  rows
# CHUNK 1703  has  30000  rows
# CHUNK 1704  has  30000  rows
# took 1.337 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801556.raw
# CHUNK 1705  has  30000  rows
# CHUNK 1706  has  30000  rows
# CHUNK 1707  has  30000  rows
# CHUNK 1708  has  30000  rows
# CHUNK 1709  has  30000  rows
# CHUNK 1710  has  30000  rows
# CHUNK 1711  has  30000  rows
# CHUNK 1712  has  30000  rows
# CHUNK 1713  has  30000  rows
# CHUNK 1714  has  30000  rows
# CHUNK 1715  has  30000  rows
# CHUNK 1716  has  30000  rows
# CHUNK 1717  has  30000  rows
# CHUNK 1718  has  30000  rows
# CHUNK 1719  has  30000  rows
# CHUNK 1720  has  30000  rows
# CHUNK 1721  has  30000  rows
# CHUNK 1722  has  30000  rows
# CHUNK 1723  has  30000  rows
# CHUNK 1724  has  30000  rows
# CHUNK 1725  has  30000  rows
# CHUNK 1726  has  30000  rows
# CHUNK 1727  has  30000  rows
# CHUNK 1728  has  30000  rows
# CHUNK 1729  has  30000  rows
# CHUNK 1730  has  30000  rows
# CHUNK 1731  has  30000  rows
# CHUNK 1732  has  30000  rows
# CHUNK 1733  has  30000  rows
# CHUNK 1734  has  30000  rows
# CHUNK 1735  has  30000  rows
# CHUNK 1736  has  30000  rows
# CHUNK 1737  has  30000  rows
# took 1.291 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801572.raw
# CHUNK 1738  has  30000  rows
# CHUNK 1739  has  30000  rows
# CHUNK 1740  has  30000  rows
# CHUNK 1741  has  30000  rows
# CHUNK 1742  has  30000  rows
# CHUNK 1743  has  30000  rows
# CHUNK 1744  has  30000  rows
# CHUNK 1745  has  30000  rows
# CHUNK 1746  has  30000  rows
# CHUNK 1747  has  30000  rows
# CHUNK 1748  has  30000  rows
# CHUNK 1749  has  30000  rows
# CHUNK 1750  has  30000  rows
# CHUNK 1751  has  30000  rows
# CHUNK 1752  has  30000  rows
# CHUNK 1753  has  30000  rows
# CHUNK 1754  has  30000  rows
# CHUNK 1755  has  30000  rows
# CHUNK 1756  has  30000  rows
# CHUNK 1757  has  30000  rows
# CHUNK 1758  has  30000  rows
# CHUNK 1759  has  30000  rows
# CHUNK 1760  has  30000  rows
# CHUNK 1761  has  30000  rows
# CHUNK 1762  has  30000  rows
# CHUNK 1763  has  30000  rows
# CHUNK 1764  has  30000  rows
# CHUNK 1765  has  30000  rows
# CHUNK 1766  has  30000  rows
# CHUNK 1767  has  30000  rows
# CHUNK 1768  has  30000  rows
# CHUNK 1769  has  30000  rows
# CHUNK 1770  has  30000  rows
# CHUNK 1771  has  30000  rows
# CHUNK 1772  has  30000  rows
# CHUNK 1773  has  30000  rows
# CHUNK 1774  has  30000  rows
# CHUNK 1775  has  30000  rows
# CHUNK 1776  has  30000  rows
# CHUNK 1777  has  30000  rows
# CHUNK 1778  has  30000  rows
# CHUNK 1779  has  30000  rows
# CHUNK 1780  has  30000  rows
# CHUNK 1781  has  30000  rows
# CHUNK 1782  has  30000  rows
# CHUNK 1783  has  30000  rows
# CHUNK 1784  has  30000  rows
# CHUNK 1785  has  30000  rows
# CHUNK 1786  has  30000  rows
# CHUNK 1787  has  30000  rows
# CHUNK 1788  has  30000  rows
# CHUNK 1789  has  30000  rows
# CHUNK 1790  has  30000  rows
# CHUNK 1791  has  30000  rows
# CHUNK 1792  has  30000  rows
# CHUNK 1793  has  30000  rows
# CHUNK 1794  has  30000  rows
# took 1.355 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801600.raw
# CHUNK 1795  has  30000  rows
# CHUNK 1796  has  30000  rows
# CHUNK 1797  has  30000  rows
# CHUNK 1798  has  30000  rows
# CHUNK 1799  has  30000  rows
# CHUNK 1800  has  30000  rows
# CHUNK 1801  has  30000  rows
# CHUNK 1802  has  30000  rows
# CHUNK 1803  has  30000  rows
# CHUNK 1804  has  30000  rows
# CHUNK 1805  has  30000  rows
# CHUNK 1806  has  30000  rows
# CHUNK 1807  has  30000  rows
# CHUNK 1808  has  30000  rows
# CHUNK 1809  has  30000  rows
# CHUNK 1810  has  30000  rows
# CHUNK 1811  has  30000  rows
# CHUNK 1812  has  30000  rows
# CHUNK 1813  has  30000  rows
# CHUNK 1814  has  30000  rows
# CHUNK 1815  has  30000  rows
# CHUNK 1816  has  30000  rows
# CHUNK 1817  has  30000  rows
# CHUNK 1818  has  30000  rows
# CHUNK 1819  has  30000  rows
# CHUNK 1820  has  30000  rows
# CHUNK 1821  has  30000  rows
# CHUNK 1822  has  30000  rows
# CHUNK 1823  has  30000  rows
# CHUNK 1824  has  30000  rows
# CHUNK 1825  has  30000  rows
# CHUNK 1826  has  30000  rows
# CHUNK 1827  has  30000  rows
# took 1.309 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801616.raw
# CHUNK 1828  has  30000  rows
# CHUNK 1829  has  30000  rows
# CHUNK 1830  has  30000  rows
# CHUNK 1831  has  30000  rows
# CHUNK 1832  has  30000  rows
# CHUNK 1833  has  30000  rows
# CHUNK 1834  has  30000  rows
# CHUNK 1835  has  30000  rows
# CHUNK 1836  has  30000  rows
# CHUNK 1837  has  30000  rows
# CHUNK 1838  has  30000  rows
# CHUNK 1839  has  30000  rows
# CHUNK 1840  has  30000  rows
# CHUNK 1841  has  30000  rows
# CHUNK 1842  has  30000  rows
# CHUNK 1843  has  30000  rows
# CHUNK 1844  has  30000  rows
# CHUNK 1845  has  30000  rows
# CHUNK 1846  has  30000  rows
# CHUNK 1847  has  30000  rows
# CHUNK 1848  has  30000  rows
# CHUNK 1849  has  30000  rows
# CHUNK 1850  has  30000  rows
# CHUNK 1851  has  30000  rows
# CHUNK 1852  has  30000  rows
# CHUNK 1853  has  30000  rows
# CHUNK 1854  has  30000  rows
# CHUNK 1855  has  30000  rows
# CHUNK 1856  has  30000  rows
# CHUNK 1857  has  30000  rows
# CHUNK 1858  has  30000  rows
# CHUNK 1859  has  30000  rows
# CHUNK 1860  has  30000  rows
# CHUNK 1861  has  30000  rows
# CHUNK 1862  has  30000  rows
# CHUNK 1863  has  30000  rows
# CHUNK 1864  has  30000  rows
# CHUNK 1865  has  30000  rows
# CHUNK 1866  has  30000  rows
# CHUNK 1867  has  30000  rows
# CHUNK 1868  has  30000  rows
# CHUNK 1869  has  30000  rows
# CHUNK 1870  has  30000  rows
# CHUNK 1871  has  30000  rows
# CHUNK 1872  has  30000  rows
# CHUNK 1873  has  30000  rows
# CHUNK 1874  has  30000  rows
# CHUNK 1875  has  30000  rows
# CHUNK 1876  has  30000  rows
# CHUNK 1877  has  30000  rows
# CHUNK 1878  has  30000  rows
# CHUNK 1879  has  30000  rows
# CHUNK 1880  has  30000  rows
# CHUNK 1881  has  30000  rows
# CHUNK 1882  has  30000  rows
# CHUNK 1883  has  30000  rows
# CHUNK 1884  has  30000  rows
# CHUNK 1885  has  30000  rows
# took 1.318 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801644.raw
# CHUNK 1886  has  30000  rows
# CHUNK 1887  has  30000  rows
# CHUNK 1888  has  30000  rows
# CHUNK 1889  has  30000  rows
# CHUNK 1890  has  30000  rows
# CHUNK 1891  has  30000  rows
# CHUNK 1892  has  30000  rows
# CHUNK 1893  has  30000  rows
# CHUNK 1894  has  30000  rows
# CHUNK 1895  has  30000  rows
# CHUNK 1896  has  30000  rows
# CHUNK 1897  has  30000  rows
# CHUNK 1898  has  30000  rows
# CHUNK 1899  has  30000  rows
# CHUNK 1900  has  30000  rows
# CHUNK 1901  has  30000  rows
# CHUNK 1902  has  30000  rows
# CHUNK 1903  has  30000  rows
# CHUNK 1904  has  30000  rows
# CHUNK 1905  has  30000  rows
# CHUNK 1906  has  30000  rows
# CHUNK 1907  has  30000  rows
# CHUNK 1908  has  30000  rows
# CHUNK 1909  has  30000  rows
# CHUNK 1910  has  30000  rows
# CHUNK 1911  has  30000  rows
# CHUNK 1912  has  30000  rows
# CHUNK 1913  has  30000  rows
# CHUNK 1914  has  30000  rows
# CHUNK 1915  has  30000  rows
# CHUNK 1916  has  30000  rows
# CHUNK 1917  has  30000  rows
# took 1.360 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801661.raw
# CHUNK 1918  has  30000  rows
# CHUNK 1919  has  30000  rows
# CHUNK 1920  has  30000  rows
# CHUNK 1921  has  30000  rows
# CHUNK 1922  has  30000  rows
# CHUNK 1923  has  30000  rows
# CHUNK 1924  has  30000  rows
# CHUNK 1925  has  30000  rows
# CHUNK 1926  has  30000  rows
# CHUNK 1927  has  30000  rows
# CHUNK 1928  has  30000  rows
# CHUNK 1929  has  30000  rows
# CHUNK 1930  has  30000  rows
# CHUNK 1931  has  30000  rows
# CHUNK 1932  has  30000  rows
# CHUNK 1933  has  30000  rows
# CHUNK 1934  has  30000  rows
# CHUNK 1935  has  30000  rows
# CHUNK 1936  has  30000  rows
# CHUNK 1937  has  30000  rows
# CHUNK 1938  has  30000  rows
# CHUNK 1939  has  30000  rows
# CHUNK 1940  has  30000  rows
# CHUNK 1941  has  30000  rows
# CHUNK 1942  has  30000  rows
# CHUNK 1943  has  30000  rows
# CHUNK 1944  has  30000  rows
# CHUNK 1945  has  30000  rows
# CHUNK 1946  has  30000  rows
# CHUNK 1947  has  30000  rows
# CHUNK 1948  has  30000  rows
# CHUNK 1949  has  30000  rows
# CHUNK 1950  has  30000  rows
# CHUNK 1951  has  30000  rows
# CHUNK 1952  has  30000  rows
# CHUNK 1953  has  30000  rows
# CHUNK 1954  has  30000  rows
# CHUNK 1955  has  30000  rows
# CHUNK 1956  has  30000  rows
# CHUNK 1957  has  30000  rows
# CHUNK 1958  has  30000  rows
# CHUNK 1959  has  30000  rows
# CHUNK 1960  has  30000  rows
# CHUNK 1961  has  30000  rows
# CHUNK 1962  has  30000  rows
# CHUNK 1963  has  30000  rows
# CHUNK 1964  has  30000  rows
# CHUNK 1965  has  30000  rows
# CHUNK 1966  has  30000  rows
# CHUNK 1967  has  30000  rows
# CHUNK 1968  has  30000  rows
# CHUNK 1969  has  30000  rows
# CHUNK 1970  has  30000  rows
# CHUNK 1971  has  30000  rows
# CHUNK 1972  has  30000  rows
# CHUNK 1973  has  30000  rows
# CHUNK 1974  has  30000  rows
# CHUNK 1975  has  30000  rows
# took 1.314 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars1_2024/baseband/17218/1721801689.raw
# CHUNK 1976  has  30000  rows
# CHUNK 1977  has  30000  rows
# CHUNK 1978  has  30000  rows
# CHUNK 1979  has  30000  rows
# CHUNK 1980  has  30000  rows
# CHUNK 1981  has  30000  rows
# CHUNK 1982  has  30000  rows
# CHUNK 1983  has  30000  rows
# CHUNK 1984  has  30000  rows
# CHUNK 1985  has  30000  rows
# CHUNK 1986  has  30000  rows
# CHUNK 1987  has  30000  rows
# CHUNK 1988  has  30000  rows
# CHUNK 1989  has  30000  rows
# CHUNK 1990  has  30000  rows
# CHUNK 1991  has  30000  rows
# CHUNK 1992  has  30000  rows
# CHUNK 1993  has  30000  rows
# CHUNK 1994  has  30000  rows
# CHUNK 1995  has  30000  rows
# CHUNK 1996  has  30000  rows
# CHUNK 1997  has  30000  rows
# CHUNK 1998  has  30000  rows
# CHUNK 1999  has  30000  rows
# CHUNK 2000  has  30000  rows
# CHUNK 2001  has  30000  rows
# CHUNK 2002  has  30000  rows
# CHUNK 2003  has  30000  rows
# CHUNK 2004  has  30000  rows
# CHUNK 2005  has  30000  rows
# CHUNK 2006  has  30000  rows
# CHUNK 2007  has  30000  rows
# CHUNK 2008  has  30000  rows
# took 1.348 seconds to read raw data on  /scratch/s/sievers/mohanagr/mars2_2024/baseband/17218/1721801705.raw
# CHUNK 2009  has  30000  rows
# CHUNK 2010  has  30000  rows
# CHUNK 2011  has  30000  rows
# CHUNK 2012  has  30000  rows
# CHUNK 2013  has  30000  rows
# CHUNK 2014  has  30000  rows
# CHUNK 2015  has  30000  rows
# CHUNK 2016  has  30000  rows
# CHUNK 2017  has  30000  rows
# CHUNK 2018  has  30000  rows
# CHUNK 2019  has  30000  rows
# CHUNK 2020  has  30000  rows
# CHUNK 2021  has  30000  rows
# CHUNK 2022  has  30000  rows
# CHUNK 2023  has  30000  rows
# CHUNK 2024  has  30000  rows
# CHUNK 2025  has  30000  rows
# CHUNK 2026  has  30000  rows
# CHUNK 2027  has  30000  rows
# CHUNK 2028  has  30000  rows
# CHUNK 2029  has  30000  rows
# CHUNK 2030  has  30000  rows
# CHUNK 2031  has  30000  rows
# CHUNK 2032  has  30000  rows
# CHUNK 2033  has  30000  rows
# Time taken final: 105.79061007499695

# %%
isolated_time = 803
vis_phase = np.angle(visibility_phased)

# vis_phase_1clk = np.angle(visibility_1clk)
plt.xlabel("Channel Index (~60kHz interval)")
plt.ylabel("Chunk Number (~0.5s interval)")
plt.title("Phase over Satellite Pulse")
plt.imshow(vis_phase[:isolated_time,:], aspect='auto',cmap='RdBu',interpolation="none")

plt.colorbar()

# %%
plt.xlabel("Chunk Number (~0.5s interval)")
plt.ylabel("Phase (Radians)")
plt.title("Unrwapped Phase over Satellite Pulse")
plt.plot(np.unwrap(vis_phase[0:isolated_time,2]))
