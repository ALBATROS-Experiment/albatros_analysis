# %%
import os
import sys
from os import path
sys.path.insert(0, "/home/thomasb")
from albatros_analysis.src.utils import baseband_utils as butils
from albatros_analysis.src.utils import orbcomm_utils as outils
from albatros_analysis.src.correlations import baseband_data_classes as bdc
import numpy as np
import cupy as cp
import json
from albatros_analysis.scripts.orbcomm import sat_utils as su
import sat_utils_gpu as sug
import figures as fgs
import argparse
import time
import matplotlib.pyplot as plt
from albatros_analysis.scripts.xcorr import helper as hp
from albatros_analysis.scripts.xcorr import helper_gpu as hpg
# Out:
# BDC is using numpy
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 12
#      10 import json
#      11 from albatros_analysis.scripts.orbcomm import sat_utils as su
# ---> 12 import sat_utils_gpu as sug
#      13 import figures as fgs
#      14 import argparse
#
# ModuleNotFoundError: No module named 'sat_utils_gpu'

# %%
T_SPECTRA = 4096/(250*10**6)
print(f'{T_SPECTRA} seconds')
print(f'{T_SPECTRA*10**6} microseconds')
nseconds = 10
nspectra = int(10/(T_SPECTRA))
print('nspectra', nspectra)
n = np.arange(nspectra)  #say we're working over 100 spectra

freq = 130 * 10**6
chan = 1836
c1 = 2 * np.pi * freq  # radians per second (lots!)
c2 = 2 * np.pi * chan  #radians per spectrum period (less!)

a = 4   #nanoseconds per second
alpha = a*10**(-9)  #spectra per spectrum
print(f'alpha {alpha}')
# Out:
# 1.6384e-05 seconds
# 16.384 microseconds
# nspectra 610351
# alpha 4e-09
