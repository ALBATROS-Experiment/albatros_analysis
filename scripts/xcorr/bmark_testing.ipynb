# %%
import numpy as np
import time
import psutil
import h5py
import scripts.xcorr.pyuv_helper as ph
from pyuvdata import UVData

# %%
filename=f'/scratch/thomasb/test_vis_{int(time.time())}.uvh5'
configname='/home/thomasb/albatros_analysis/scripts/xcorr/config/config_gpu_7ant_jul21_band2_1hr.json'
print(filename)
print(configname)
# Out:
# /scratch/thomasb/test_vis_1763661759.uvh5
# /home/thomasb/albatros_analysis/scripts/xcorr/config/config_gpu_7ant_jul21_band2_1hr.json
