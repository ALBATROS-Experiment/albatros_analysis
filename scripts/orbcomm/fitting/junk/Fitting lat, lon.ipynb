# %%
import numpy as np
from orbcomm_phase_obj import get_phase
from scipy.optimize import least_squares as lsq
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 from orbcomm_phase_obj import get_phase
#       3 from scipy.optimize import least_squares as lsq
#       4 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'orbcomm_phase_obj'

# %%
# myargs=(1627439234,484,'FM118',1839,'./niagara/pols_4bit_1627439234_10000_2947_0_None.npz')
# myargs=(1627441379,325,'FM110',1839,'./niagara/pols_4bit_1627441379_10000_1959_0_None.npz')
# coords=[51.4641921 , -68.23484134] # fit using data1 old
coords1 = [ 51.46419021, -68.2348457 ] #fit using data1
coords2 = [51.46418956, -68.23485163] #fit using data2
old_coords = [51.4642, -68.23486]
# new_coords = [51.4646065, -68.2352594]
new_coords = [51.4641932, -68.2348603]

# %%
#new coords from 2022 Uapishka trip 1

chisq, simphase, predphase, obsphase = get_phase(new_coords,*myargs)
# Out:
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC

# %%
plt.plot(obsphase-predphase)

# %%
chisq, simphase1, predphase1, obsphase1 = get_phase(old_coords,*myargs)
chisq2, simphase2, predphase2, obsphase2 = get_phase(coords1,*myargs)
# Out:
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC

# %%
chisq2, simphase3, predphase3, obsphase3 = get_phase(coords2,*myargs)
# Out:
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC

# %%
res1=obsphase2-predphase2 #res for data2, fit using 1
res2=obsphase3-predphase3 #res for data2, fit using 2
plt.plot(res1-res2)

# %%
print(np.mean(res1),np.mean(res2),np.std(res1),np.std(res2))
# Out:
# -0.224638932888747 0.13841993151065923 0.5101503510362425 0.4098524755502361

# %%
t10000=10000*2048/125e6
f=plt.gcf()
f.set_size_inches(8,4)
plt.suptitle('phase residuals of data2')
plt.subplot(121)
plt.plot(np.arange(predphase1.shape[0])*t10000,obsphase1-predphase1)
plt.title('Using old coordinates')
plt.xlabel('seconds')
plt.subplot(122)
plt.plot(np.arange(predphase1.shape[0])*t10000,obsphase2-predphase2)
plt.title('Using new coordinates')
plt.xlabel('seconds')
# Out:
# Text(0.5, 0, 'seconds')

# %%
t10000=10000*2048/125e6
f=plt.gcf()
f.set_size_inches(8,4)
plt.suptitle('phase residuals of data2, fit using data2')
plt.subplot(121)
plt.plot(np.arange(predphase1.shape[0])*t10000,obsphase1-predphase1)
plt.title('Using old coordinates')
plt.xlabel('seconds')
plt.subplot(122)
plt.plot(np.arange(predphase1.shape[0])*t10000,obsphase3-predphase3)
plt.title('Using new coordinates')
plt.xlabel('seconds')
# Out:
# Text(0.5, 0, 'seconds')

# %%
myargs=(1627439234,484,'FM118',1839,'./niagara/pols_4bit_1627439234_10000_2947_0_None.npz')
coords2 = [51.46418956, -68.23485163]
old_coords = [51.4642, -68.23486]
chisq, simphase1, predphase1, obsphase1 = get_phase(old_coords,*myargs)
chisq2, simphase2, predphase2, obsphase2 = get_phase(coords2,*myargs)
# Out:
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC

# %%
t10000=10000*2048/125e6
f=plt.gcf()
f.set_size_inches(8,4)
plt.suptitle('phase residuals of data1, fit using data2')
plt.subplot(121)
plt.plot(np.arange(predphase1.shape[0])*t10000,obsphase1-predphase1)
plt.title('Using old coordinates')
plt.xlabel('seconds')
plt.subplot(122)
plt.plot(np.arange(predphase1.shape[0])*t10000,obsphase2-predphase2)
plt.title('Using new coordinates')
plt.xlabel('seconds')
# Out:
# Text(0.5, 0, 'seconds')

# %%
np.std(obsphase2-predphase2)
# Out:
# 0.3281963392870361

# %%
myargs=(1627439234,484,'FM118',1839,'./niagara/pols_4bit_1627439234_10000_2947_0_None.npz')
coords1 = [ 51.46419021, -68.2348457 ]
coords2 = [51.46418956, -68.23485163]
old_coords = [51.4642, -68.23486]
chisq, simphase1, predphase1, obsphase1 = get_phase(old_coords,*myargs)
chisq2, simphase2, predphase2, obsphase2 = get_phase(coords1,*myargs)
# Out:
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC

# %%
t10000=10000*2048/125e6
f=plt.gcf()
f.set_size_inches(8,4)
plt.suptitle('phase residuals of data1, fit using data1')
plt.subplot(121)
plt.plot(np.arange(predphase1.shape[0])*t10000,obsphase1-predphase1)
plt.title('Using old coordinates')
plt.xlabel('seconds')
plt.subplot(122)
plt.plot(np.arange(predphase1.shape[0])*t10000,obsphase2-predphase2)
plt.title('Using new coordinates')
plt.xlabel('seconds')
# Out:
# Text(0.5, 0, 'seconds')

# %%
def haversine_np(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees)

    All args must be of equal length.    

    """
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2

    c = 2 * np.arcsin(np.sqrt(a))
    km = 6367 * c
    return km

# %%
haversine_np(*coords, *old_coords)*1000
# Out:
# 2.0989903009276385

# %%
haversine_np(*coords1, *coords2)*1000
# Out:
# 0.6595160010927892

# %%
err = 2*np.pi*137e6 * 2 /3e8
print(err)
# Out:
# 5.738642580557355

# %%
1/(2*np.pi*137e6)
# Out:
# 1.1617149130795281e-09

# %%
#fitting for data 1
myargs=(1627439234,484,'FM118',1839,'./niagara/pols_4bit_1627439234_10000_2947_0_None.npz')
old_coords = [51.4642, -68.23486]
lsq(get_phase, old_coords, args=myargs)
# Out:
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC
# niter is 484
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM118 [+] catalog #41183 epoch 2021-07-27 12:46:24 UTC
# ...

# %%
#fitting for data2
myargs=(1627441379,325,'FM110',1839,'./niagara/pols_4bit_1627441379_10000_1959_0_None.npz')
old_coords = [51.4642, -68.23486]
lsq(get_phase, old_coords, args=myargs)
# Out:
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC
# niter is 325
# Chanidx is 37
# FREQ 137.75634765625  MHz
# ORBCOMM FM110 [+] catalog #41182 epoch 2021-07-27 19:55:29 UTC
# ...
