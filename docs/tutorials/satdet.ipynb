# %% [markdown]
# # **Satellite Detection**
# ## Learning Objectives
# This notebook is used to show the user how satellites are detected in the ALBATROS data. We wish to extract two key pieces of information from this script: spectrum number offsets between antenna, and the exact satellite passes which have high SNR and low RFI. The production code for this process is essentially a faster and more general version of the notebook outlined below, so all analytical and data processing decisions can be seen in this notebook.
